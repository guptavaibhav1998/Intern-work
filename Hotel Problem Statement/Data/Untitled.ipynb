# %%
import pandas as pd
import numpy as np
import datetime

# %%
data=pd.read_csv('seasonalityData.csv')

# %%
data
# Out:
#      Unnamed: 0  RoomsBooked
# 0    2015-07-01           64
# 1    2015-07-02           65
# 2    2015-07-03           13
# 3    2015-07-04           22
# 4    2015-07-05           12
# 5    2015-07-06           11
# 6    2015-07-07           12
# 7    2015-07-08           25
# 8    2015-07-09           25
# 9    2015-07-10            6
# 10   2015-07-11           37
# 11   2015-07-12           33
# 12   2015-07-13           32
# 13   2015-07-14            2
# 14   2015-07-15           22
# 15   2015-07-16           22
# 16   2015-07-17           55
# 17   2015-07-18           95
# 18   2015-07-19           40
# 19   2015-07-20           22
# 20   2015-07-21           15
# 21   2015-07-22           24
# 22   2015-07-23           59
# 23   2015-07-24            0
# 24   2015-07-25           56
# 25   2015-07-26           33
# 26   2015-07-27           57
# 27   2015-07-28           46
# 28   2015-07-29           19
# 29   2015-07-30           14
# ..          ...          ...
# ...
