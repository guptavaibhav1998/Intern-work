# %% [markdown]
# # Problem
# Suppose you are in charge of the diet plan for high school lunch. Your job is to make sure that the students get the right balance of nutrition from the chosen food.
# However, there are some restrictions in terms of budget and the variety of food that needs to be in the diet to make it interesting. The following table shows, in detail, the complete nutritional value for each food item, and their maximum/minimum daily intake.

# %% [markdown]
# <img src="1.png">

# %% [markdown]
# The discrete optimization problem is simple: Minimize the cost of the lunch given these constraints (on total calories but also on each of the nutritional component e.g. cholesterol, vitamin A, calcium, etc.

# %%
import pandas as pd
from pulp import *

# %% [markdown]
# ### Read the given nutrition dataset into a Pandas DataFrame object
# Note we are reading only the first 64 rows with `nrows=64` argument because we just want to read all the nutrients informtion and not the maximum/minimum bounds in the dataset. We will enter those bounds in the optimization problem separately.

# %%
df = pd.read_excel("diet.xls",nrows=64)

# %% [markdown]
# ### Show first 5 rows of the dataset

# %%
df.head()
# Out:
#                  Foods  Price/ Serving      Serving Size  Calories  \
# 0      Frozen Broccoli            0.16         10 Oz Pkg      73.8
# 1          Carrots,Raw            0.07  1/2 Cup Shredded      23.7
# 2          Celery, Raw            0.04           1 Stalk       6.4
# 3          Frozen Corn            0.18           1/2 Cup      72.2
# 4  Lettuce,Iceberg,Raw            0.02            1 Leaf       2.6
#
#    Cholesterol mg  Total_Fat g  Sodium mg  Carbohydrates g  Dietary_Fiber g  \
# 0             0.0          0.8       68.2             13.6              8.5
# 1             0.0          0.1       19.2              5.6              1.6
# 2             0.0          0.1       34.8              1.5              0.7
# 3             0.0          0.6        2.5             17.1              2.0
# 4             0.0          0.0        1.8              0.4              0.3
#
#    Protein g  Vit_A IU  Vit_C IU  Calcium mg  Iron mg
# 0        8.0    5867.4     160.2       159.0      2.3
# 1        0.6   15471.0       5.1        14.9      0.3
# 2        0.3      53.6       2.8        16.0      0.2
# 3        2.5     106.6       5.2         3.3      0.3
# 4        0.2      66.0       0.8         3.8      0.1

# %% [markdown]
# ### Create the `PuLP` problem variable. Since it is a cost minimization problem, we need to use `LpMinimize`

# %%
# Create the 'prob' variable to contain the problem data
prob = LpProblem("Simple Diet Problem",LpMinimize)

# %% [markdown]
# ### Create a list of food items from the dataset

# %%
# Creates a list of the Ingredients
food_items = list(df['Foods'])

# %%
print("So, the food items to consdier, are\n"+"-"*100)
for f in food_items:
    print(f,end=', ')
# Out:
# So, the food items to consdier, are
# ----------------------------------------------------------------------------------------------------
# Frozen Broccoli, Carrots,Raw, Celery, Raw, Frozen Corn, Lettuce,Iceberg,Raw, Peppers, Sweet, Raw, Potatoes, Baked, Tofu, Roasted Chicken, Spaghetti W/ Sauce, Tomato,Red,Ripe,Raw, Apple,Raw,W/Skin, Banana, Grapes, Kiwifruit,Raw,Fresh, Oranges, Bagels, Wheat Bread, White Bread, Oatmeal Cookies, Apple Pie, Chocolate Chip Cookies, Butter,Regular, Cheddar Cheese, 3.3% Fat,Whole Milk, 2% Lowfat Milk, Skim Milk, Poached Eggs, Scrambled Eggs, Bologna,Turkey, Frankfurter, Beef, Ham,Sliced,Extralean, Kielbasa,Prk, Cap'N Crunch, Cheerios, Corn Flks, Kellogg'S, Raisin Brn, Kellg'S, Rice Krispies, Special K, Oatmeal, Malt-O-Meal,Choc, Pizza W/Pepperoni, Taco, Hamburger W/Toppings, Hotdog, Plain, Couscous, White Rice, Macaroni,Ckd, Peanut Butter, Pork, Sardines in Oil, White Tuna in Water, Popcorn,Air-Popped, Potato Chips,Bbqflvr, Pretzels, Tortilla Chip, Chicknoodl Soup, Splt Pea&Hamsoup, Vegetbeef Soup, Neweng Clamchwd, Tomato Soup, New E Clamchwd,W/Mlk, Crm Mshrm Soup,W/Mlk, Beanbacn Soup,W/Watr,

# %% [markdown]
# ### Create a dictinary of costs for all food items

# %%
costs = dict(zip(food_items,df['Price/ Serving']))

# %%
#costs

# %% [markdown]
# ### Create a dictionary of calories for all food items

# %%
calories = dict(zip(food_items,df['Calories']))
#calories

# %% [markdown]
# ### Create a dictionary of cholesterol for all food items

# %%
cholesterol = dict(zip(food_items,df['Cholesterol mg']))
#cholesterol

# %% [markdown]
# ### Create a dictionary of total fat for all food items

# %%
fat = dict(zip(food_items,df['Total_Fat g']))
#fat

# %% [markdown]
# ### Create a dictionary of sodium for all food items

# %%
sodium = dict(zip(food_items,df['Sodium mg']))
sodium
# Out:
# {'Frozen Broccoli': 68.2,
#  'Carrots,Raw': 19.2,
#  'Celery, Raw': 34.8,
#  'Frozen Corn': 2.5,
#  'Lettuce,Iceberg,Raw': 1.8,
#  'Peppers, Sweet, Raw': 1.5,
#  'Potatoes, Baked': 15.2,
#  'Tofu': 8.1,
#  'Roasted Chicken': 125.6,
#  'Spaghetti W/ Sauce': 1237.1,
#  'Tomato,Red,Ripe,Raw': 11.1,
#  'Apple,Raw,W/Skin': 0.0,
#  'Banana': 1.1,
#  'Grapes': 0.5,
#  'Kiwifruit,Raw,Fresh': 3.8,
#  'Oranges': 0.0,
#  'Bagels': 151.4,
#  'Wheat Bread': 134.5,
#  'White Bread': 132.5,
#  'Oatmeal Cookies': 68.9,
#  'Apple Pie': 75.4,
#  'Chocolate Chip Cookies': 57.8,
#  'Butter,Regular': 41.3,
#  'Cheddar Cheese': 173.7,
#  '3.3% Fat,Whole Milk': 119.6,
#  '2% Lowfat Milk': 121.8,
#  'Skim Milk': 126.2,
#  'Poached Eggs': 140.0,
#  'Scrambled Eggs': 168.0,
#  'Bologna,Turkey': 248.9,
#  'Frankfurter, Beef': 461.7,
#  'Ham,Sliced,Extralean': 405.1,
#  'Kielbasa,Prk': 279.8,
#  "Cap'N Crunch": 213.3,
#  'Cheerios': 307.6,
#  "Corn Flks, Kellogg'S": 290.5,
#  "Raisin Brn, Kellg'S": 204.4,
#  'Rice Krispies': 340.8,
#  'Special K': 265.5,
#  'Oatmeal': 2.3,
#  'Malt-O-Meal,Choc': 16.5,
#  'Pizza W/Pepperoni': 267.0,
#  'Taco': 802.0,
#  'Hamburger W/Toppings': 563.9,
#  'Hotdog, Plain': 670.3,
#  'Couscous': 4.5,
#  'White Rice': 0.8,
#  'Macaroni,Ckd': 0.7,
#  'Peanut Butter': 155.5,
#  'Pork': 38.4,
#  'Sardines in Oil': 121.2,
#  'White Tuna in Water': 333.2,
#  'Popcorn,Air-Popped': 1.1,
#  'Potato Chips,Bbqflvr': 212.6,
#  'Pretzels': 486.2,
#  'Tortilla Chip': 149.7,
#  'Chicknoodl Soup': 1862.2,
#  'Splt Pea&Hamsoup': 964.8,
#  'Vegetbeef Soup': 1915.1,
#  'Neweng Clamchwd': 1864.9,
#  'Tomato Soup': 1744.4,
#  'New E Clamchwd,W/Mlk': 992.0,
#  'Crm Mshrm Soup,W/Mlk': 1076.3,
#  'Beanbacn Soup,W/Watr': 951.3}

# %% [markdown]
# ### Create a dictionary of carbohydrates for all food items

# %%
carbs = dict(zip(food_items,df['Carbohydrates g']))
carbs
# Out:
# {'Frozen Broccoli': 13.6,
#  'Carrots,Raw': 5.6,
#  'Celery, Raw': 1.5,
#  'Frozen Corn': 17.1,
#  'Lettuce,Iceberg,Raw': 0.4,
#  'Peppers, Sweet, Raw': 4.8,
#  'Potatoes, Baked': 39.9,
#  'Tofu': 2.2,
#  'Roasted Chicken': 0.0,
#  'Spaghetti W/ Sauce': 58.3,
#  'Tomato,Red,Ripe,Raw': 5.7,
#  'Apple,Raw,W/Skin': 21.0,
#  'Banana': 26.7,
#  'Grapes': 4.1,
#  'Kiwifruit,Raw,Fresh': 11.3,
#  'Oranges': 15.4,
#  'Bagels': 15.1,
#  'Wheat Bread': 12.4,
#  'White Bread': 11.8,
#  'Oatmeal Cookies': 12.4,
#  'Apple Pie': 9.6,
#  'Chocolate Chip Cookies': 9.3,
#  'Butter,Regular': 0.0,
#  'Cheddar Cheese': 0.4,
#  '3.3% Fat,Whole Milk': 11.4,
#  '2% Lowfat Milk': 11.7,
#  'Skim Milk': 11.9,
#  'Poached Eggs': 0.6,
#  'Scrambled Eggs': 1.3,
#  'Bologna,Turkey': 0.3,
#  'Frankfurter, Beef': 0.8,
#  'Ham,Sliced,Extralean': 0.3,
#  'Kielbasa,Prk': 0.6,
#  "Cap'N Crunch": 23.0,
#  'Cheerios': 19.6,
#  "Corn Flks, Kellogg'S": 24.5,
#  "Raisin Brn, Kellg'S": 27.9,
#  'Rice Krispies': 24.8,
#  'Special K': 21.3,
#  'Oatmeal': 25.3,
#  'Malt-O-Meal,Choc': 128.2,
#  'Pizza W/Pepperoni': 19.9,
#  'Taco': 26.7,
#  'Hamburger W/Toppings': 32.7,
#  'Hotdog, Plain': 18.0,
#  'Couscous': 20.9,
#  'White Rice': 22.3,
#  'Macaroni,Ckd': 19.8,
#  'Peanut Butter': 6.9,
#  'Pork': 0.0,
#  'Sardines in Oil': 0.0,
#  'White Tuna in Water': 0.0,
#  'Popcorn,Air-Popped': 22.1,
#  'Potato Chips,Bbqflvr': 15.0,
#  'Pretzels': 22.5,
#  'Tortilla Chip': 17.8,
#  'Chicknoodl Soup': 18.7,
#  'Splt Pea&Hamsoup': 26.8,
#  'Vegetbeef Soup': 20.4,
#  'Neweng Clamchwd': 21.8,
#  'Tomato Soup': 33.2,
#  'New E Clamchwd,W/Mlk': 16.6,
#  'Crm Mshrm Soup,W/Mlk': 15.0,
#  'Beanbacn Soup,W/Watr': 22.8}

# %% [markdown]
# ### Create a dictionary of dietary fiber for all food items

# %%
fiber = dict(zip(food_items,df['Dietary_Fiber g']))
fiber
# Out:
# {'Frozen Broccoli': 8.5,
#  'Carrots,Raw': 1.6,
#  'Celery, Raw': 0.7,
#  'Frozen Corn': 2.0,
#  'Lettuce,Iceberg,Raw': 0.3,
#  'Peppers, Sweet, Raw': 1.3,
#  'Potatoes, Baked': 3.2,
#  'Tofu': 1.4,
#  'Roasted Chicken': 0.0,
#  'Spaghetti W/ Sauce': 11.6,
#  'Tomato,Red,Ripe,Raw': 1.4,
#  'Apple,Raw,W/Skin': 3.7,
#  'Banana': 2.7,
#  'Grapes': 0.2,
#  'Kiwifruit,Raw,Fresh': 2.6,
#  'Oranges': 3.1,
#  'Bagels': 0.6,
#  'Wheat Bread': 1.3,
#  'White Bread': 1.1,
#  'Oatmeal Cookies': 0.6,
#  'Apple Pie': 0.5,
#  'Chocolate Chip Cookies': 0.0,
#  'Butter,Regular': 0.0,
#  'Cheddar Cheese': 0.0,
#  '3.3% Fat,Whole Milk': 0.0,
#  '2% Lowfat Milk': 0.0,
#  'Skim Milk': 0.0,
#  'Poached Eggs': 0.0,
#  'Scrambled Eggs': 0.0,
#  'Bologna,Turkey': 0.0,
#  'Frankfurter, Beef': 0.0,
#  'Ham,Sliced,Extralean': 0.0,
#  'Kielbasa,Prk': 0.0,
#  "Cap'N Crunch": 0.5,
#  'Cheerios': 2.0,
#  "Corn Flks, Kellogg'S": 0.7,
#  "Raisin Brn, Kellg'S": 4.0,
#  'Rice Krispies': 0.4,
#  'Special K': 0.7,
#  'Oatmeal': 4.0,
#  'Malt-O-Meal,Choc': 0.0,
#  'Pizza W/Pepperoni': 0.0,
#  'Taco': 0.0,
#  'Hamburger W/Toppings': 0.0,
#  'Hotdog, Plain': 0.0,
#  'Couscous': 1.3,
#  'White Rice': 0.3,
#  'Macaroni,Ckd': 0.9,
#  'Peanut Butter': 2.1,
#  'Pork': 0.0,
#  'Sardines in Oil': 0.0,
#  'White Tuna in Water': 0.0,
#  'Popcorn,Air-Popped': 4.3,
#  'Potato Chips,Bbqflvr': 1.2,
#  'Pretzels': 0.9,
#  'Tortilla Chip': 1.8,
#  'Chicknoodl Soup': 1.5,
#  'Splt Pea&Hamsoup': 4.1,
#  'Vegetbeef Soup': 4.0,
#  'Neweng Clamchwd': 1.5,
#  'Tomato Soup': 1.0,
#  'New E Clamchwd,W/Mlk': 1.5,
#  'Crm Mshrm Soup,W/Mlk': 0.5,
#  'Beanbacn Soup,W/Watr': 8.6}

# %% [markdown]
# ### Create a dictionary of protein for all food items

# %%
protein = dict(zip(food_items,df['Protein g']))
protein
# Out:
# {'Frozen Broccoli': 8.0,
#  'Carrots,Raw': 0.6,
#  'Celery, Raw': 0.3,
#  'Frozen Corn': 2.5,
#  'Lettuce,Iceberg,Raw': 0.2,
#  'Peppers, Sweet, Raw': 0.7,
#  'Potatoes, Baked': 3.7,
#  'Tofu': 9.4,
#  'Roasted Chicken': 42.2,
#  'Spaghetti W/ Sauce': 8.2,
#  'Tomato,Red,Ripe,Raw': 1.0,
#  'Apple,Raw,W/Skin': 0.3,
#  'Banana': 1.2,
#  'Grapes': 0.2,
#  'Kiwifruit,Raw,Fresh': 0.8,
#  'Oranges': 1.2,
#  'Bagels': 3.0,
#  'Wheat Bread': 2.2,
#  'White Bread': 2.3,
#  'Oatmeal Cookies': 1.1,
#  'Apple Pie': 0.5,
#  'Chocolate Chip Cookies': 0.9,
#  'Butter,Regular': 0.0,
#  'Cheddar Cheese': 7.0,
#  '3.3% Fat,Whole Milk': 8.0,
#  '2% Lowfat Milk': 8.1,
#  'Skim Milk': 8.4,
#  'Poached Eggs': 6.2,
#  'Scrambled Eggs': 6.7,
#  'Bologna,Turkey': 3.9,
#  'Frankfurter, Beef': 5.4,
#  'Ham,Sliced,Extralean': 5.5,
#  'Kielbasa,Prk': 3.4,
#  "Cap'N Crunch": 1.4,
#  'Cheerios': 4.3,
#  "Corn Flks, Kellogg'S": 2.3,
#  "Raisin Brn, Kellg'S": 4.0,
#  'Rice Krispies': 1.9,
#  'Special K': 5.6,
#  'Oatmeal': 6.1,
#  'Malt-O-Meal,Choc': 17.3,
#  'Pizza W/Pepperoni': 10.1,
#  'Taco': 20.7,
#  'Hamburger W/Toppings': 13.6,
#  'Hotdog, Plain': 10.4,
#  'Couscous': 3.4,
#  'White Rice': 2.1,
#  'Macaroni,Ckd': 3.3,
#  'Peanut Butter': 7.7,
#  'Pork': 13.8,
#  'Sardines in Oil': 5.9,
#  'White Tuna in Water': 22.7,
#  'Popcorn,Air-Popped': 3.4,
#  'Potato Chips,Bbqflvr': 2.2,
#  'Pretzels': 2.6,
#  'Tortilla Chip': 2.0,
#  'Chicknoodl Soup': 7.9,
#  'Splt Pea&Hamsoup': 11.1,
#  'Vegetbeef Soup': 11.2,
#  'Neweng Clamchwd': 10.9,
#  'Tomato Soup': 4.1,
#  'New E Clamchwd,W/Mlk': 9.5,
#  'Crm Mshrm Soup,W/Mlk': 6.1,
#  'Beanbacn Soup,W/Watr': 7.9}

# %% [markdown]
# ### Create a dictionary of vitamin A for all food items

# %%
vit_A = dict(zip(food_items,df['Vit_A IU']))
vit_A
# Out:
# {'Frozen Broccoli': 5867.4,
#  'Carrots,Raw': 15471.0,
#  'Celery, Raw': 53.6,
#  'Frozen Corn': 106.6,
#  'Lettuce,Iceberg,Raw': 66.0,
#  'Peppers, Sweet, Raw': 467.7,
#  'Potatoes, Baked': 0.0,
#  'Tofu': 98.6,
#  'Roasted Chicken': 77.4,
#  'Spaghetti W/ Sauce': 3055.2,
#  'Tomato,Red,Ripe,Raw': 766.3,
#  'Apple,Raw,W/Skin': 73.1,
#  'Banana': 92.3,
#  'Grapes': 24.0,
#  'Kiwifruit,Raw,Fresh': 133.0,
#  'Oranges': 268.6,
#  'Bagels': 0.0,
#  'Wheat Bread': 0.0,
#  'White Bread': 0.0,
#  'Oatmeal Cookies': 2.9,
#  'Apple Pie': 35.2,
#  'Chocolate Chip Cookies': 101.8,
#  'Butter,Regular': 152.9,
#  'Cheddar Cheese': 296.5,
#  '3.3% Fat,Whole Milk': 307.4,
#  '2% Lowfat Milk': 500.2,
#  'Skim Milk': 499.8,
#  'Poached Eggs': 316.0,
#  'Scrambled Eggs': 409.2,
#  'Bologna,Turkey': 0.0,
#  'Frankfurter, Beef': 0.0,
#  'Ham,Sliced,Extralean': 0.0,
#  'Kielbasa,Prk': 0.0,
#  "Cap'N Crunch": 40.6,
#  'Cheerios': 1252.2,
#  "Corn Flks, Kellogg'S": 1252.2,
#  "Raisin Brn, Kellg'S": 1250.2,
#  'Rice Krispies': 1252.2,
#  'Special K': 1252.2,
#  'Oatmeal': 37.4,
#  'Malt-O-Meal,Choc': 0.0,
#  'Pizza W/Pepperoni': 281.9,
#  'Taco': 855.0,
#  'Hamburger W/Toppings': 126.3,
#  'Hotdog, Plain': 0.0,
#  'Couscous': 0.0,
#  'White Rice': 0.0,
#  'Macaroni,Ckd': 0.0,
#  'Peanut Butter': 0.0,
#  'Pork': 14.7,
#  'Sardines in Oil': 53.8,
#  'White Tuna in Water': 68.0,
#  'Popcorn,Air-Popped': 55.6,
#  'Potato Chips,Bbqflvr': 61.5,
#  'Pretzels': 0.0,
#  'Tortilla Chip': 55.6,
#  'Chicknoodl Soup': 1308.7,
#  'Splt Pea&Hamsoup': 4872.0,
#  'Vegetbeef Soup': 3785.1,
#  'Neweng Clamchwd': 20.1,
#  'Tomato Soup': 1393.0,
#  'New E Clamchwd,W/Mlk': 163.7,
#  'Crm Mshrm Soup,W/Mlk': 153.8,
#  'Beanbacn Soup,W/Watr': 888.0}

# %% [markdown]
# ### Create a dictionary of vitamin C for all food items

# %%
vit_C = dict(zip(food_items,df['Vit_C IU']))
vit_C
# Out:
# {'Frozen Broccoli': 160.2,
#  'Carrots,Raw': 5.1,
#  'Celery, Raw': 2.8,
#  'Frozen Corn': 5.2,
#  'Lettuce,Iceberg,Raw': 0.8,
#  'Peppers, Sweet, Raw': 66.1,
#  'Potatoes, Baked': 15.6,
#  'Tofu': 0.1,
#  'Roasted Chicken': 0.0,
#  'Spaghetti W/ Sauce': 27.9,
#  'Tomato,Red,Ripe,Raw': 23.5,
#  'Apple,Raw,W/Skin': 7.9,
#  'Banana': 10.4,
#  'Grapes': 1.0,
#  'Kiwifruit,Raw,Fresh': 74.5,
#  'Oranges': 69.7,
#  'Bagels': 0.0,
#  'Wheat Bread': 0.0,
#  'White Bread': 0.0,
#  'Oatmeal Cookies': 0.1,
#  'Apple Pie': 0.9,
#  'Chocolate Chip Cookies': 0.0,
#  'Butter,Regular': 0.0,
#  'Cheddar Cheese': 0.0,
#  '3.3% Fat,Whole Milk': 2.3,
#  '2% Lowfat Milk': 2.3,
#  'Skim Milk': 2.4,
#  'Poached Eggs': 0.0,
#  'Scrambled Eggs': 0.1,
#  'Bologna,Turkey': 0.0,
#  'Frankfurter, Beef': 10.8,
#  'Ham,Sliced,Extralean': 7.4,
#  'Kielbasa,Prk': 5.5,
#  "Cap'N Crunch": 0.0,
#  'Cheerios': 15.1,
#  "Corn Flks, Kellogg'S": 15.1,
#  "Raisin Brn, Kellg'S": 0.0,
#  'Rice Krispies': 15.1,
#  'Special K': 15.1,
#  'Oatmeal': 0.0,
#  'Malt-O-Meal,Choc': 0.0,
#  'Pizza W/Pepperoni': 1.6,
#  'Taco': 2.2,
#  'Hamburger W/Toppings': 2.6,
#  'Hotdog, Plain': 0.1,
#  'Couscous': 0.0,
#  'White Rice': 0.0,
#  'Macaroni,Ckd': 0.0,
#  'Peanut Butter': 0.0,
#  'Pork': 0.0,
#  'Sardines in Oil': 0.0,
#  'White Tuna in Water': 0.0,
#  'Popcorn,Air-Popped': 0.0,
#  'Potato Chips,Bbqflvr': 9.6,
#  'Pretzels': 0.0,
#  'Tortilla Chip': 0.0,
#  'Chicknoodl Soup': 0.0,
#  'Splt Pea&Hamsoup': 7.0,
#  'Vegetbeef Soup': 4.8,
#  'Neweng Clamchwd': 4.8,
#  'Tomato Soup': 133.0,
#  'New E Clamchwd,W/Mlk': 3.5,
#  'Crm Mshrm Soup,W/Mlk': 2.2,
#  'Beanbacn Soup,W/Watr': 1.5}

# %% [markdown]
# ### Create a dictionary of calcium for all food items

# %%
calcium = dict(zip(food_items,df['Calcium mg']))
calcium
# Out:
# {'Frozen Broccoli': 159.0,
#  'Carrots,Raw': 14.9,
#  'Celery, Raw': 16.0,
#  'Frozen Corn': 3.3,
#  'Lettuce,Iceberg,Raw': 3.8,
#  'Peppers, Sweet, Raw': 6.7,
#  'Potatoes, Baked': 22.7,
#  'Tofu': 121.8,
#  'Roasted Chicken': 21.9,
#  'Spaghetti W/ Sauce': 80.2,
#  'Tomato,Red,Ripe,Raw': 6.2,
#  'Apple,Raw,W/Skin': 9.7,
#  'Banana': 6.8,
#  'Grapes': 3.4,
#  'Kiwifruit,Raw,Fresh': 19.8,
#  'Oranges': 52.4,
#  'Bagels': 21.0,
#  'Wheat Bread': 10.8,
#  'White Bread': 26.2,
#  'Oatmeal Cookies': 6.7,
#  'Apple Pie': 3.1,
#  'Chocolate Chip Cookies': 6.2,
#  'Butter,Regular': 1.2,
#  'Cheddar Cheese': 202.0,
#  '3.3% Fat,Whole Milk': 291.3,
#  '2% Lowfat Milk': 296.7,
#  'Skim Milk': 302.3,
#  'Poached Eggs': 24.5,
#  'Scrambled Eggs': 42.6,
#  'Bologna,Turkey': 23.8,
#  'Frankfurter, Beef': 9.0,
#  'Ham,Sliced,Extralean': 2.0,
#  'Kielbasa,Prk': 11.4,
#  "Cap'N Crunch": 4.8,
#  'Cheerios': 48.6,
#  "Corn Flks, Kellogg'S": 0.9,
#  "Raisin Brn, Kellg'S": 12.9,
#  'Rice Krispies': 4.0,
#  'Special K': 8.2,
#  'Oatmeal': 18.7,
#  'Malt-O-Meal,Choc': 23.1,
#  'Pizza W/Pepperoni': 64.6,
#  'Taco': 220.6,
#  'Hamburger W/Toppings': 51.4,
#  'Hotdog, Plain': 23.5,
#  'Couscous': 7.2,
#  'White Rice': 7.9,
#  'Macaroni,Ckd': 4.9,
#  'Peanut Butter': 13.1,
#  'Pork': 59.9,
#  'Sardines in Oil': 91.7,
#  'White Tuna in Water': 3.4,
#  'Popcorn,Air-Popped': 2.8,
#  'Potato Chips,Bbqflvr': 14.2,
#  'Pretzels': 10.2,
#  'Tortilla Chip': 43.7,
#  'Chicknoodl Soup': 27.1,
#  'Splt Pea&Hamsoup': 33.6,
#  'Vegetbeef Soup': 32.6,
#  'Neweng Clamchwd': 82.8,
#  'Tomato Soup': 27.6,
#  'New E Clamchwd,W/Mlk': 186.0,
#  'Crm Mshrm Soup,W/Mlk': 178.6,
#  'Beanbacn Soup,W/Watr': 81.0}

# %% [markdown]
# ### Create a dictionary of iron for all food items

# %%
iron = dict(zip(food_items,df['Iron mg']))
iron
# Out:
# {'Frozen Broccoli': 2.3,
#  'Carrots,Raw': 0.3,
#  'Celery, Raw': 0.2,
#  'Frozen Corn': 0.3,
#  'Lettuce,Iceberg,Raw': 0.1,
#  'Peppers, Sweet, Raw': 0.3,
#  'Potatoes, Baked': 4.3,
#  'Tofu': 6.2,
#  'Roasted Chicken': 1.8,
#  'Spaghetti W/ Sauce': 2.3,
#  'Tomato,Red,Ripe,Raw': 0.6,
#  'Apple,Raw,W/Skin': 0.2,
#  'Banana': 0.4,
#  'Grapes': 0.1,
#  'Kiwifruit,Raw,Fresh': 0.3,
#  'Oranges': 0.1,
#  'Bagels': 1.0,
#  'Wheat Bread': 0.7,
#  'White Bread': 0.8,
#  'Oatmeal Cookies': 0.5,
#  'Apple Pie': 0.1,
#  'Chocolate Chip Cookies': 0.4,
#  'Butter,Regular': 0.0,
#  'Cheddar Cheese': 0.2,
#  '3.3% Fat,Whole Milk': 0.1,
#  '2% Lowfat Milk': 0.1,
#  'Skim Milk': 0.1,
#  'Poached Eggs': 0.7,
#  'Scrambled Eggs': 0.7,
#  'Bologna,Turkey': 0.4,
#  'Frankfurter, Beef': 0.6,
#  'Ham,Sliced,Extralean': 0.2,
#  'Kielbasa,Prk': 0.4,
#  "Cap'N Crunch": 7.5,
#  'Cheerios': 4.5,
#  "Corn Flks, Kellogg'S": 1.8,
#  "Raisin Brn, Kellg'S": 16.8,
#  'Rice Krispies': 1.8,
#  'Special K': 4.5,
#  'Oatmeal': 1.6,
#  'Malt-O-Meal,Choc': 4.7,
#  'Pizza W/Pepperoni': 0.9,
#  'Taco': 2.4,
#  'Hamburger W/Toppings': 2.5,
#  'Hotdog, Plain': 2.3,
#  'Couscous': 0.3,
#  'White Rice': 0.9,
#  'Macaroni,Ckd': 1.0,
#  'Peanut Butter': 0.6,
#  'Pork': 0.4,
#  'Sardines in Oil': 0.7,
#  'White Tuna in Water': 0.5,
#  'Popcorn,Air-Popped': 0.8,
#  'Potato Chips,Bbqflvr': 0.5,
#  'Pretzels': 1.2,
#  'Tortilla Chip': 0.4,
#  'Chicknoodl Soup': 1.5,
#  'Splt Pea&Hamsoup': 2.1,
#  'Vegetbeef Soup': 2.2,
#  'Neweng Clamchwd': 2.8,
#  'Tomato Soup': 3.5,
#  'New E Clamchwd,W/Mlk': 1.5,
#  'Crm Mshrm Soup,W/Mlk': 0.6,
#  'Beanbacn Soup,W/Watr': 2.0}

# %% [markdown]
# ### Create a dictionary of food portion with lower bound 0 - these are the main optimization variables

# %%
# A dictionary called 'food_vars' is created to contain the referenced Variables
food_vars = LpVariable.dicts("Portion",food_items,0,cat='Continuous')
food_vars
# Out:
# {'Frozen Broccoli': Portion_Frozen_Broccoli,
#  'Carrots,Raw': Portion_Carrots,Raw,
#  'Celery, Raw': Portion_Celery,_Raw,
#  'Frozen Corn': Portion_Frozen_Corn,
#  'Lettuce,Iceberg,Raw': Portion_Lettuce,Iceberg,Raw,
#  'Peppers, Sweet, Raw': Portion_Peppers,_Sweet,_Raw,
#  'Potatoes, Baked': Portion_Potatoes,_Baked,
#  'Tofu': Portion_Tofu,
#  'Roasted Chicken': Portion_Roasted_Chicken,
#  'Spaghetti W/ Sauce': Portion_Spaghetti_W__Sauce,
#  'Tomato,Red,Ripe,Raw': Portion_Tomato,Red,Ripe,Raw,
#  'Apple,Raw,W/Skin': Portion_Apple,Raw,W_Skin,
#  'Banana': Portion_Banana,
#  'Grapes': Portion_Grapes,
#  'Kiwifruit,Raw,Fresh': Portion_Kiwifruit,Raw,Fresh,
#  'Oranges': Portion_Oranges,
#  'Bagels': Portion_Bagels,
#  'Wheat Bread': Portion_Wheat_Bread,
#  'White Bread': Portion_White_Bread,
#  'Oatmeal Cookies': Portion_Oatmeal_Cookies,
#  'Apple Pie': Portion_Apple_Pie,
#  'Chocolate Chip Cookies': Portion_Chocolate_Chip_Cookies,
#  'Butter,Regular': Portion_Butter,Regular,
#  'Cheddar Cheese': Portion_Cheddar_Cheese,
#  '3.3% Fat,Whole Milk': Portion_3.3%_Fat,Whole_Milk,
#  '2% Lowfat Milk': Portion_2%_Lowfat_Milk,
#  'Skim Milk': Portion_Skim_Milk,
#  'Poached Eggs': Portion_Poached_Eggs,
#  'Scrambled Eggs': Portion_Scrambled_Eggs,
#  'Bologna,Turkey': Portion_Bologna,Turkey,
#  'Frankfurter, Beef': Portion_Frankfurter,_Beef,
#  'Ham,Sliced,Extralean': Portion_Ham,Sliced,Extralean,
#  'Kielbasa,Prk': Portion_Kielbasa,Prk,
#  "Cap'N Crunch": Portion_Cap'N_Crunch,
#  'Cheerios': Portion_Cheerios,
#  "Corn Flks, Kellogg'S": Portion_Corn_Flks,_Kellogg'S,
#  "Raisin Brn, Kellg'S": Portion_Raisin_Brn,_Kellg'S,
#  'Rice Krispies': Portion_Rice_Krispies,
#  'Special K': Portion_Special_K,
#  'Oatmeal': Portion_Oatmeal,
#  'Malt-O-Meal,Choc': Portion_Malt_O_Meal,Choc,
#  'Pizza W/Pepperoni': Portion_Pizza_W_Pepperoni,
#  'Taco': Portion_Taco,
#  'Hamburger W/Toppings': Portion_Hamburger_W_Toppings,
#  'Hotdog, Plain': Portion_Hotdog,_Plain,
#  'Couscous': Portion_Couscous,
#  'White Rice': Portion_White_Rice,
#  'Macaroni,Ckd': Portion_Macaroni,Ckd,
#  'Peanut Butter': Portion_Peanut_Butter,
#  'Pork': Portion_Pork,
#  'Sardines in Oil': Portion_Sardines_in_Oil,
#  'White Tuna in Water': Portion_White_Tuna_in_Water,
#  'Popcorn,Air-Popped': Portion_Popcorn,Air_Popped,
#  'Potato Chips,Bbqflvr': Portion_Potato_Chips,Bbqflvr,
#  'Pretzels': Portion_Pretzels,
#  'Tortilla Chip': Portion_Tortilla_Chip,
#  'Chicknoodl Soup': Portion_Chicknoodl_Soup,
#  'Splt Pea&Hamsoup': Portion_Splt_Pea&Hamsoup,
#  'Vegetbeef Soup': Portion_Vegetbeef_Soup,
#  'Neweng Clamchwd': Portion_Neweng_Clamchwd,
#  'Tomato Soup': Portion_Tomato_Soup,
#  'New E Clamchwd,W/Mlk': Portion_New_E_Clamchwd,W_Mlk,
#  'Crm Mshrm Soup,W/Mlk': Portion_Crm_Mshrm_Soup,W_Mlk,
#  'Beanbacn Soup,W/Watr': Portion_Beanbacn_Soup,W_Watr}

# %% [markdown]
# ### Create another set of variables for each food, with integer 0 or 1. These are indicator variables

# %%
# A dictionary called 'food_chosen' is created ,these are just indicators
food_chosen = LpVariable.dicts("Chosen",food_items,0,1,cat='Integer')
food_chosen
# Out:
# {'Frozen Broccoli': Chosen_Frozen_Broccoli,
#  'Carrots,Raw': Chosen_Carrots,Raw,
#  'Celery, Raw': Chosen_Celery,_Raw,
#  'Frozen Corn': Chosen_Frozen_Corn,
#  'Lettuce,Iceberg,Raw': Chosen_Lettuce,Iceberg,Raw,
#  'Peppers, Sweet, Raw': Chosen_Peppers,_Sweet,_Raw,
#  'Potatoes, Baked': Chosen_Potatoes,_Baked,
#  'Tofu': Chosen_Tofu,
#  'Roasted Chicken': Chosen_Roasted_Chicken,
#  'Spaghetti W/ Sauce': Chosen_Spaghetti_W__Sauce,
#  'Tomato,Red,Ripe,Raw': Chosen_Tomato,Red,Ripe,Raw,
#  'Apple,Raw,W/Skin': Chosen_Apple,Raw,W_Skin,
#  'Banana': Chosen_Banana,
#  'Grapes': Chosen_Grapes,
#  'Kiwifruit,Raw,Fresh': Chosen_Kiwifruit,Raw,Fresh,
#  'Oranges': Chosen_Oranges,
#  'Bagels': Chosen_Bagels,
#  'Wheat Bread': Chosen_Wheat_Bread,
#  'White Bread': Chosen_White_Bread,
#  'Oatmeal Cookies': Chosen_Oatmeal_Cookies,
#  'Apple Pie': Chosen_Apple_Pie,
#  'Chocolate Chip Cookies': Chosen_Chocolate_Chip_Cookies,
#  'Butter,Regular': Chosen_Butter,Regular,
#  'Cheddar Cheese': Chosen_Cheddar_Cheese,
#  '3.3% Fat,Whole Milk': Chosen_3.3%_Fat,Whole_Milk,
#  '2% Lowfat Milk': Chosen_2%_Lowfat_Milk,
#  'Skim Milk': Chosen_Skim_Milk,
#  'Poached Eggs': Chosen_Poached_Eggs,
#  'Scrambled Eggs': Chosen_Scrambled_Eggs,
#  'Bologna,Turkey': Chosen_Bologna,Turkey,
#  'Frankfurter, Beef': Chosen_Frankfurter,_Beef,
#  'Ham,Sliced,Extralean': Chosen_Ham,Sliced,Extralean,
#  'Kielbasa,Prk': Chosen_Kielbasa,Prk,
#  "Cap'N Crunch": Chosen_Cap'N_Crunch,
#  'Cheerios': Chosen_Cheerios,
#  "Corn Flks, Kellogg'S": Chosen_Corn_Flks,_Kellogg'S,
#  "Raisin Brn, Kellg'S": Chosen_Raisin_Brn,_Kellg'S,
#  'Rice Krispies': Chosen_Rice_Krispies,
#  'Special K': Chosen_Special_K,
#  'Oatmeal': Chosen_Oatmeal,
#  'Malt-O-Meal,Choc': Chosen_Malt_O_Meal,Choc,
#  'Pizza W/Pepperoni': Chosen_Pizza_W_Pepperoni,
#  'Taco': Chosen_Taco,
#  'Hamburger W/Toppings': Chosen_Hamburger_W_Toppings,
#  'Hotdog, Plain': Chosen_Hotdog,_Plain,
#  'Couscous': Chosen_Couscous,
#  'White Rice': Chosen_White_Rice,
#  'Macaroni,Ckd': Chosen_Macaroni,Ckd,
#  'Peanut Butter': Chosen_Peanut_Butter,
#  'Pork': Chosen_Pork,
#  'Sardines in Oil': Chosen_Sardines_in_Oil,
#  'White Tuna in Water': Chosen_White_Tuna_in_Water,
#  'Popcorn,Air-Popped': Chosen_Popcorn,Air_Popped,
#  'Potato Chips,Bbqflvr': Chosen_Potato_Chips,Bbqflvr,
#  'Pretzels': Chosen_Pretzels,
#  'Tortilla Chip': Chosen_Tortilla_Chip,
#  'Chicknoodl Soup': Chosen_Chicknoodl_Soup,
#  'Splt Pea&Hamsoup': Chosen_Splt_Pea&Hamsoup,
#  'Vegetbeef Soup': Chosen_Vegetbeef_Soup,
#  'Neweng Clamchwd': Chosen_Neweng_Clamchwd,
#  'Tomato Soup': Chosen_Tomato_Soup,
#  'New E Clamchwd,W/Mlk': Chosen_New_E_Clamchwd,W_Mlk,
#  'Crm Mshrm Soup,W/Mlk': Chosen_Crm_Mshrm_Soup,W_Mlk,
#  'Beanbacn Soup,W/Watr': Chosen_Beanbacn_Soup,W_Watr}

# %% [markdown]
# ### Adding the objective function to the problem

# %%
# The objective function is added to 'prob' first
prob += lpSum([costs[i]*food_vars[i] for i in food_items]), "Total Cost of the balanced diet"

# %% [markdown]
# ### Adding the calorie constraints to the problem

# %%
prob += lpSum([calories[f] * food_vars[f] for f in food_items]) >= 1500.0, "CalorieMinimum"
prob += lpSum([calories[f] * food_vars[f] for f in food_items]) <= 2500.0, "CalorieMaximum"

# %% [markdown]
# ### Adding other nutrient constraints to the problem one by one...

# %%
# Cholesterol
prob += lpSum([cholesterol[f] * food_vars[f] for f in food_items]) >= 30.0, "CholesterolMinimum"
prob += lpSum([cholesterol[f] * food_vars[f] for f in food_items]) <= 240.0, "CholesterolMaximum"

# Fat
prob += lpSum([fat[f] * food_vars[f] for f in food_items]) >= 20.0, "FatMinimum"
prob += lpSum([fat[f] * food_vars[f] for f in food_items]) <= 70.0, "FatMaximum"

# Sodium
prob += lpSum([sodium[f] * food_vars[f] for f in food_items]) >= 800.0, "SodiumMinimum"
prob += lpSum([sodium[f] * food_vars[f] for f in food_items]) <= 2000.0, "SodiumMaximum"

# Carbs
prob += lpSum([carbs[f] * food_vars[f] for f in food_items]) >= 130.0, "CarbsMinimum"
prob += lpSum([carbs[f] * food_vars[f] for f in food_items]) <= 450.0, "CarbsMaximum"

# Fiber
prob += lpSum([fiber[f] * food_vars[f] for f in food_items]) >= 125.0, "FiberMinimum"
prob += lpSum([fiber[f] * food_vars[f] for f in food_items]) <= 250.0, "FiberMaximum"

# Protein
prob += lpSum([protein[f] * food_vars[f] for f in food_items]) >= 60.0, "ProteinMinimum"
prob += lpSum([protein[f] * food_vars[f] for f in food_items]) <= 100.0, "ProteinMaximum"

# Vitamin A
prob += lpSum([vit_A[f] * food_vars[f] for f in food_items]) >= 1000.0, "VitaminAMinimum"
prob += lpSum([vit_A[f] * food_vars[f] for f in food_items]) <= 10000.0, "VitaminAMaximum"

# Vitamin C
prob += lpSum([vit_C[f] * food_vars[f] for f in food_items]) >= 400.0, "VitaminCMinimum"
prob += lpSum([vit_C[f] * food_vars[f] for f in food_items]) <= 5000.0, "VitaminCMaximum"

# Calcium
prob += lpSum([calcium[f] * food_vars[f] for f in food_items]) >= 700.0, "CalciumMinimum"
prob += lpSum([calcium[f] * food_vars[f] for f in food_items]) <= 1500.0, "CalciumMaximum"

# Iron
prob += lpSum([iron[f] * food_vars[f] for f in food_items]) >= 10.0, "IronMinimum"
prob += lpSum([iron[f] * food_vars[f] for f in food_items]) <= 40.0, "IronMaximum"

# %% [markdown]
# ### Adding constraint linking `food_vars` and `food_chosen`

# %%
#for f in food_items:
#    print(food_chosen[f]*0.1)
#    prob += food_vars[f]>= food_chosen[f]*0.1
#    prob += food_vars[f]<= food_chosen[f]*1e5

# %% [markdown]
# ### Adding constraint of celery and frozen broccoli

# %%
prob += food_chosen['Frozen Broccoli']+food_chosen['Celery, Raw']<=1

# %% [markdown]
# ### Adding constraint of at least 3 types of meat/poultry/fish/eggs in every diet

# %%
protein_choices = ['Beanbacn Soup,W/Watr','Bologna,Turkey','Frankfurter, Beef','Ham,Sliced,Extralean',
                  'Hamburger W/Toppings','Hotdog, Plain','Kielbasa,Prk','Neweng Clamchwd','Pizza W/Pepperoni',
                  'Poached Eggs','Pork','Roasted Chicken','Sardines in Oil','Scrambled Eggs','Vegetbeef Soup',
                   'White Tuna in Water']

# %%
prob += lpSum([food_chosen[p] for p in protein_choices]) >= 3.0

# %%
#print(prob)
# Out:
# Simple Diet Problem:
# MINIMIZE
# 0.23*Portion_2%_Lowfat_Milk + 0.16*Portion_3.3%_Fat,Whole_Milk + 0.24*Portion_Apple,Raw,W_Skin + 0.16*Portion_Apple_Pie + 0.16*Portion_Bagels + 0.15*Portion_Banana + 0.67*Portion_Beanbacn_Soup,W_Watr + 0.15*Portion_Bologna,Turkey + 0.05*Portion_Butter,Regular + 0.31*Portion_Cap'N_Crunch + 0.07*Portion_Carrots,Raw + 0.04*Portion_Celery,_Raw + 0.25*Portion_Cheddar_Cheese + 0.28*Portion_Cheerios + 0.39*Portion_Chicknoodl_Soup + 0.03*Portion_Chocolate_Chip_Cookies + 0.28*Portion_Corn_Flks,_Kellogg'S + 0.39*Portion_Couscous + 0.65*Portion_Crm_Mshrm_Soup,W_Mlk + 0.27*Portion_Frankfurter,_Beef + 0.16*Portion_Frozen_Broccoli + 0.18*Portion_Frozen_Corn + 0.32*Portion_Grapes + 0.33*Portion_Ham,Sliced,Extralean + 0.83*Portion_Hamburger_W_Toppings + 0.31*Portion_Hotdog,_Plain + 0.15*Portion_Kielbasa,Prk + 0.49*Portion_Kiwifruit,Raw,Fresh + 0.02*Portion_Lettuce,Iceberg,Raw + 0.17*Portion_Macaroni,Ckd + 0.52*Portion_Malt_O_Meal,Choc + 0.99*Portion_New_E_Clamchwd,W_Mlk + 0.75*Portion_Neweng_Clamchwd + 0.82*Portion_Oatmeal + 0.09*Portion_Oatmeal_Cookies + 0.15*Portion_Oranges + 0.07*Portion_Peanut_Butter + 0.53*Portion_Peppers,_Sweet,_Raw + 0.44*Portion_Pizza_W_Pepperoni + 0.08*Portion_Poached_Eggs + 0.04*Portion_Popcorn,Air_Popped + 0.81*Portion_Pork + 0.22*Portion_Potato_Chips,Bbqflvr + 0.06*Portion_Potatoes,_Baked + 0.12*Portion_Pretzels + 0.34*Portion_Raisin_Brn,_Kellg'S + 0.32*Portion_Rice_Krispies + 0.84*Portion_Roasted_Chicken + 0.45*Portion_Sardines_in_Oil + 0.11*Portion_Scrambled_Eggs + 0.13*Portion_Skim_Milk + 0.78*Portion_Spaghetti_W__Sauce + 0.38*Portion_Special_K + 0.67*Portion_Splt_Pea&Hamsoup + 0.59*Portion_Taco + 0.31*Portion_Tofu + 0.27*Portion_Tomato,Red,Ripe,Raw + 0.39*Portion_Tomato_Soup + 0.19*Portion_Tortilla_Chip + 0.71*Portion_Vegetbeef_Soup + 0.05*Portion_Wheat_Bread + 0.06*Portion_White_Bread + 0.08*Portion_White_Rice + 0.69*Portion_White_Tuna_in_Water + 0.0
# SUBJECT TO
# CalorieMinimum: 121.2 Portion_2%_Lowfat_Milk
#  + 149.9 Portion_3.3%_Fat,Whole_Milk + 81.4 Portion_Apple,Raw,W_Skin
#  + 67.2 Portion_Apple_Pie + 78 Portion_Bagels + 104.9 Portion_Banana
#  + 172 Portion_Beanbacn_Soup,W_Watr + 56.4 Portion_Bologna,Turkey
#  + 35.8 Portion_Butter,Regular + 119.6 Portion_Cap'N_Crunch
#  + 23.7 Portion_Carrots,Raw + 6.4 Portion_Celery,_Raw
#  + 112.7 Portion_Cheddar_Cheese + 111 Portion_Cheerios
#  + 150.1 Portion_Chicknoodl_Soup + 78.1 Portion_Chocolate_Chip_Cookies
#  + 110.5 Portion_Corn_Flks,_Kellogg'S + 100.8 Portion_Couscous
#  + 203.4 Portion_Crm_Mshrm_Soup,W_Mlk + 141.8 Portion_Frankfurter,_Beef
#  + 73.8 Portion_Frozen_Broccoli + 72.2 Portion_Frozen_Corn
#  + 15.1 Portion_Grapes + 37.1 Portion_Ham,Sliced,Extralean
#  + 275 Portion_Hamburger_W_Toppings + 242.1 Portion_Hotdog,_Plain
#  + 80.6 Portion_Kielbasa,Prk + 46.4 Portion_Kiwifruit,Raw,Fresh
#  + 2.6 Portion_Lettuce,Iceberg,Raw + 98.7 Portion_Macaroni,Ckd
#  + 607.2 Portion_Malt_O_Meal,Choc + 163.7 Portion_New_E_Clamchwd,W_Mlk
#  + 175.7 Portion_Neweng_Clamchwd + 145.1 Portion_Oatmeal
#  + 81 Portion_Oatmeal_Cookies + 61.6 Portion_Oranges
#  + 188.5 Portion_Peanut_Butter + 20 Portion_Peppers,_Sweet,_Raw
#  + 181 Portion_Pizza_W_Pepperoni + 74.5 Portion_Poached_Eggs
#  + 108.3 Portion_Popcorn,Air_Popped + 710.8 Portion_Pork
#  + 139.2 Portion_Potato_Chips,Bbqflvr + 171.5 Portion_Potatoes,_Baked
#  + 108 Portion_Pretzels + 115.1 Portion_Raisin_Brn,_Kellg'S
#  + 112.2 Portion_Rice_Krispies + 277.4 Portion_Roasted_Chicken
#  + 49.9 Portion_Sardines_in_Oil + 99.6 Portion_Scrambled_Eggs
#  + 85.5 Portion_Skim_Milk + 358.2 Portion_Spaghetti_W__Sauce
#  + 110.8 Portion_Special_K + 184.8 Portion_Splt_Pea&Hamsoup
#  + 369.4 Portion_Taco + 88.2 Portion_Tofu + 25.8 Portion_Tomato,Red,Ripe,Raw
#  + 170.7 Portion_Tomato_Soup + 142 Portion_Tortilla_Chip
#  + 158.1 Portion_Vegetbeef_Soup + 65 Portion_Wheat_Bread
#  + 65 Portion_White_Bread + 102.7 Portion_White_Rice
#  + 115.6 Portion_White_Tuna_in_Water >= 1500
#
# CalorieMaximum: 121.2 Portion_2%_Lowfat_Milk
#  + 149.9 Portion_3.3%_Fat,Whole_Milk + 81.4 Portion_Apple,Raw,W_Skin
#  + 67.2 Portion_Apple_Pie + 78 Portion_Bagels + 104.9 Portion_Banana
#  + 172 Portion_Beanbacn_Soup,W_Watr + 56.4 Portion_Bologna,Turkey
#  + 35.8 Portion_Butter,Regular + 119.6 Portion_Cap'N_Crunch
#  + 23.7 Portion_Carrots,Raw + 6.4 Portion_Celery,_Raw
#  + 112.7 Portion_Cheddar_Cheese + 111 Portion_Cheerios
#  + 150.1 Portion_Chicknoodl_Soup + 78.1 Portion_Chocolate_Chip_Cookies
#  + 110.5 Portion_Corn_Flks,_Kellogg'S + 100.8 Portion_Couscous
#  + 203.4 Portion_Crm_Mshrm_Soup,W_Mlk + 141.8 Portion_Frankfurter,_Beef
#  + 73.8 Portion_Frozen_Broccoli + 72.2 Portion_Frozen_Corn
#  + 15.1 Portion_Grapes + 37.1 Portion_Ham,Sliced,Extralean
#  + 275 Portion_Hamburger_W_Toppings + 242.1 Portion_Hotdog,_Plain
#  + 80.6 Portion_Kielbasa,Prk + 46.4 Portion_Kiwifruit,Raw,Fresh
#  + 2.6 Portion_Lettuce,Iceberg,Raw + 98.7 Portion_Macaroni,Ckd
#  + 607.2 Portion_Malt_O_Meal,Choc + 163.7 Portion_New_E_Clamchwd,W_Mlk
#  + 175.7 Portion_Neweng_Clamchwd + 145.1 Portion_Oatmeal
#  + 81 Portion_Oatmeal_Cookies + 61.6 Portion_Oranges
#  + 188.5 Portion_Peanut_Butter + 20 Portion_Peppers,_Sweet,_Raw
#  + 181 Portion_Pizza_W_Pepperoni + 74.5 Portion_Poached_Eggs
#  + 108.3 Portion_Popcorn,Air_Popped + 710.8 Portion_Pork
#  + 139.2 Portion_Potato_Chips,Bbqflvr + 171.5 Portion_Potatoes,_Baked
#  + 108 Portion_Pretzels + 115.1 Portion_Raisin_Brn,_Kellg'S
#  + 112.2 Portion_Rice_Krispies + 277.4 Portion_Roasted_Chicken
#  + 49.9 Portion_Sardines_in_Oil + 99.6 Portion_Scrambled_Eggs
#  + 85.5 Portion_Skim_Milk + 358.2 Portion_Spaghetti_W__Sauce
#  + 110.8 Portion_Special_K + 184.8 Portion_Splt_Pea&Hamsoup
#  + 369.4 Portion_Taco + 88.2 Portion_Tofu + 25.8 Portion_Tomato,Red,Ripe,Raw
#  + 170.7 Portion_Tomato_Soup + 142 Portion_Tortilla_Chip
#  + 158.1 Portion_Vegetbeef_Soup + 65 Portion_Wheat_Bread
#  + 65 Portion_White_Bread + 102.7 Portion_White_Rice
#  + 115.6 Portion_White_Tuna_in_Water <= 2500
#
# CholesterolMinimum: 18.3 Portion_2%_Lowfat_Milk
#  + 33.2 Portion_3.3%_Fat,Whole_Milk + 2.5 Portion_Beanbacn_Soup,W_Watr
#  + 28.1 Portion_Bologna,Turkey + 10.9 Portion_Butter,Regular
#  + 29.4 Portion_Cheddar_Cheese + 12.3 Portion_Chicknoodl_Soup
#  + 5.1 Portion_Chocolate_Chip_Cookies + 19.8 Portion_Crm_Mshrm_Soup,W_Mlk
#  + 27.4 Portion_Frankfurter,_Beef + 13.3 Portion_Ham,Sliced,Extralean
#  + 42.8 Portion_Hamburger_W_Toppings + 44.1 Portion_Hotdog,_Plain
#  + 17.4 Portion_Kielbasa,Prk + 22.3 Portion_New_E_Clamchwd,W_Mlk
#  + 10 Portion_Neweng_Clamchwd + 14.2 Portion_Pizza_W_Pepperoni
#  + 211.5 Portion_Poached_Eggs + 105.1 Portion_Pork
#  + 129.9 Portion_Roasted_Chicken + 34.1 Portion_Sardines_in_Oil
#  + 211.2 Portion_Scrambled_Eggs + 4.4 Portion_Skim_Milk
#  + 7.2 Portion_Splt_Pea&Hamsoup + 56.4 Portion_Taco
#  + 10 Portion_Vegetbeef_Soup + 35.7 Portion_White_Tuna_in_Water >= 30
#
# CholesterolMaximum: 18.3 Portion_2%_Lowfat_Milk
#  + 33.2 Portion_3.3%_Fat,Whole_Milk + 2.5 Portion_Beanbacn_Soup,W_Watr
#  + 28.1 Portion_Bologna,Turkey + 10.9 Portion_Butter,Regular
#  + 29.4 Portion_Cheddar_Cheese + 12.3 Portion_Chicknoodl_Soup
#  + 5.1 Portion_Chocolate_Chip_Cookies + 19.8 Portion_Crm_Mshrm_Soup,W_Mlk
#  + 27.4 Portion_Frankfurter,_Beef + 13.3 Portion_Ham,Sliced,Extralean
#  + 42.8 Portion_Hamburger_W_Toppings + 44.1 Portion_Hotdog,_Plain
#  + 17.4 Portion_Kielbasa,Prk + 22.3 Portion_New_E_Clamchwd,W_Mlk
#  + 10 Portion_Neweng_Clamchwd + 14.2 Portion_Pizza_W_Pepperoni
#  + 211.5 Portion_Poached_Eggs + 105.1 Portion_Pork
#  + 129.9 Portion_Roasted_Chicken + 34.1 Portion_Sardines_in_Oil
#  + 211.2 Portion_Scrambled_Eggs + 4.4 Portion_Skim_Milk
#  + 7.2 Portion_Splt_Pea&Hamsoup + 56.4 Portion_Taco
#  + 10 Portion_Vegetbeef_Soup + 35.7 Portion_White_Tuna_in_Water <= 240
#
# FatMinimum: 4.7 Portion_2%_Lowfat_Milk + 8.1 Portion_3.3%_Fat,Whole_Milk
#  + 0.5 Portion_Apple,Raw,W_Skin + 3.1 Portion_Apple_Pie + 0.5 Portion_Bagels
#  + 0.5 Portion_Banana + 5.9 Portion_Beanbacn_Soup,W_Watr
#  + 4.3 Portion_Bologna,Turkey + 4.1 Portion_Butter,Regular
#  + 2.6 Portion_Cap'N_Crunch + 0.1 Portion_Carrots,Raw
#  + 0.1 Portion_Celery,_Raw + 9.3 Portion_Cheddar_Cheese + 1.8 Portion_Cheerios
#  + 4.6 Portion_Chicknoodl_Soup + 4.5 Portion_Chocolate_Chip_Cookies
#  + 0.1 Portion_Corn_Flks,_Kellogg'S + 0.1 Portion_Couscous
#  + 13.6 Portion_Crm_Mshrm_Soup,W_Mlk + 12.8 Portion_Frankfurter,_Beef
#  + 0.8 Portion_Frozen_Broccoli + 0.6 Portion_Frozen_Corn + 0.1 Portion_Grapes
#  + 1.4 Portion_Ham,Sliced,Extralean + 10.2 Portion_Hamburger_W_Toppings
#  + 14.5 Portion_Hotdog,_Plain + 7.1 Portion_Kielbasa,Prk
#  + 0.3 Portion_Kiwifruit,Raw,Fresh + 0.5 Portion_Macaroni,Ckd
#  + 1.5 Portion_Malt_O_Meal,Choc + 6.6 Portion_New_E_Clamchwd,W_Mlk
#  + 5 Portion_Neweng_Clamchwd + 2.3 Portion_Oatmeal
#  + 3.3 Portion_Oatmeal_Cookies + 0.2 Portion_Oranges
#  + 16 Portion_Peanut_Butter + 0.1 Portion_Peppers,_Sweet,_Raw
#  + 7 Portion_Pizza_W_Pepperoni + 5 Portion_Poached_Eggs
#  + 1.2 Portion_Popcorn,Air_Popped + 72.2 Portion_Pork
#  + 9.2 Portion_Potato_Chips,Bbqflvr + 0.2 Portion_Potatoes,_Baked
#  + Portion_Pretzels + 0.7 Portion_Raisin_Brn,_Kellg'S
#  + 0.2 Portion_Rice_Krispies + 10.8 Portion_Roasted_Chicken
#  + 2.7 Portion_Sardines_in_Oil + 7.3 Portion_Scrambled_Eggs
#  + 0.4 Portion_Skim_Milk + 12.3 Portion_Spaghetti_W__Sauce
#  + 0.1 Portion_Special_K + 4 Portion_Splt_Pea&Hamsoup + 20.6 Portion_Taco
#  + 5.5 Portion_Tofu + 0.4 Portion_Tomato,Red,Ripe,Raw
#  + 3.8 Portion_Tomato_Soup + 7.4 Portion_Tortilla_Chip
#  + 3.8 Portion_Vegetbeef_Soup + Portion_Wheat_Bread + Portion_White_Bread
#  + 0.2 Portion_White_Rice + 2.1 Portion_White_Tuna_in_Water >= 20
#
# FatMaximum: 4.7 Portion_2%_Lowfat_Milk + 8.1 Portion_3.3%_Fat,Whole_Milk
#  + 0.5 Portion_Apple,Raw,W_Skin + 3.1 Portion_Apple_Pie + 0.5 Portion_Bagels
#  + 0.5 Portion_Banana + 5.9 Portion_Beanbacn_Soup,W_Watr
#  + 4.3 Portion_Bologna,Turkey + 4.1 Portion_Butter,Regular
#  + 2.6 Portion_Cap'N_Crunch + 0.1 Portion_Carrots,Raw
#  + 0.1 Portion_Celery,_Raw + 9.3 Portion_Cheddar_Cheese + 1.8 Portion_Cheerios
#  + 4.6 Portion_Chicknoodl_Soup + 4.5 Portion_Chocolate_Chip_Cookies
#  + 0.1 Portion_Corn_Flks,_Kellogg'S + 0.1 Portion_Couscous
#  + 13.6 Portion_Crm_Mshrm_Soup,W_Mlk + 12.8 Portion_Frankfurter,_Beef
#  + 0.8 Portion_Frozen_Broccoli + 0.6 Portion_Frozen_Corn + 0.1 Portion_Grapes
#  + 1.4 Portion_Ham,Sliced,Extralean + 10.2 Portion_Hamburger_W_Toppings
#  + 14.5 Portion_Hotdog,_Plain + 7.1 Portion_Kielbasa,Prk
#  + 0.3 Portion_Kiwifruit,Raw,Fresh + 0.5 Portion_Macaroni,Ckd
#  + 1.5 Portion_Malt_O_Meal,Choc + 6.6 Portion_New_E_Clamchwd,W_Mlk
#  + 5 Portion_Neweng_Clamchwd + 2.3 Portion_Oatmeal
#  + 3.3 Portion_Oatmeal_Cookies + 0.2 Portion_Oranges
#  + 16 Portion_Peanut_Butter + 0.1 Portion_Peppers,_Sweet,_Raw
#  + 7 Portion_Pizza_W_Pepperoni + 5 Portion_Poached_Eggs
#  + 1.2 Portion_Popcorn,Air_Popped + 72.2 Portion_Pork
#  + 9.2 Portion_Potato_Chips,Bbqflvr + 0.2 Portion_Potatoes,_Baked
#  + Portion_Pretzels + 0.7 Portion_Raisin_Brn,_Kellg'S
#  + 0.2 Portion_Rice_Krispies + 10.8 Portion_Roasted_Chicken
#  + 2.7 Portion_Sardines_in_Oil + 7.3 Portion_Scrambled_Eggs
#  + 0.4 Portion_Skim_Milk + 12.3 Portion_Spaghetti_W__Sauce
#  + 0.1 Portion_Special_K + 4 Portion_Splt_Pea&Hamsoup + 20.6 Portion_Taco
#  + 5.5 Portion_Tofu + 0.4 Portion_Tomato,Red,Ripe,Raw
#  + 3.8 Portion_Tomato_Soup + 7.4 Portion_Tortilla_Chip
#  + 3.8 Portion_Vegetbeef_Soup + Portion_Wheat_Bread + Portion_White_Bread
#  + 0.2 Portion_White_Rice + 2.1 Portion_White_Tuna_in_Water <= 70
#
# SodiumMinimum: 121.8 Portion_2%_Lowfat_Milk
#  + 119.6 Portion_3.3%_Fat,Whole_Milk + 75.4 Portion_Apple_Pie
#  + 151.4 Portion_Bagels + 1.1 Portion_Banana
#  + 951.3 Portion_Beanbacn_Soup,W_Watr + 248.9 Portion_Bologna,Turkey
#  + 41.3 Portion_Butter,Regular + 213.3 Portion_Cap'N_Crunch
#  + 19.2 Portion_Carrots,Raw + 34.8 Portion_Celery,_Raw
#  + 173.7 Portion_Cheddar_Cheese + 307.6 Portion_Cheerios
#  + 1862.2 Portion_Chicknoodl_Soup + 57.8 Portion_Chocolate_Chip_Cookies
#  + 290.5 Portion_Corn_Flks,_Kellogg'S + 4.5 Portion_Couscous
#  + 1076.3 Portion_Crm_Mshrm_Soup,W_Mlk + 461.7 Portion_Frankfurter,_Beef
#  + 68.2 Portion_Frozen_Broccoli + 2.5 Portion_Frozen_Corn + 0.5 Portion_Grapes
#  + 405.1 Portion_Ham,Sliced,Extralean + 563.9 Portion_Hamburger_W_Toppings
#  + 670.3 Portion_Hotdog,_Plain + 279.8 Portion_Kielbasa,Prk
#  + 3.8 Portion_Kiwifruit,Raw,Fresh + 1.8 Portion_Lettuce,Iceberg,Raw
#  + 0.7 Portion_Macaroni,Ckd + 16.5 Portion_Malt_O_Meal,Choc
#  + 992 Portion_New_E_Clamchwd,W_Mlk + 1864.9 Portion_Neweng_Clamchwd
#  + 2.3 Portion_Oatmeal + 68.9 Portion_Oatmeal_Cookies
#  + 155.5 Portion_Peanut_Butter + 1.5 Portion_Peppers,_Sweet,_Raw
#  + 267 Portion_Pizza_W_Pepperoni + 140 Portion_Poached_Eggs
#  + 1.1 Portion_Popcorn,Air_Popped + 38.4 Portion_Pork
#  + 212.6 Portion_Potato_Chips,Bbqflvr + 15.2 Portion_Potatoes,_Baked
#  + 486.2 Portion_Pretzels + 204.4 Portion_Raisin_Brn,_Kellg'S
#  + 340.8 Portion_Rice_Krispies + 125.6 Portion_Roasted_Chicken
#  + 121.2 Portion_Sardines_in_Oil + 168 Portion_Scrambled_Eggs
#  + 126.2 Portion_Skim_Milk + 1237.1 Portion_Spaghetti_W__Sauce
#  + 265.5 Portion_Special_K + 964.8 Portion_Splt_Pea&Hamsoup + 802 Portion_Taco
#  + 8.1 Portion_Tofu + 11.1 Portion_Tomato,Red,Ripe,Raw
#  + 1744.4 Portion_Tomato_Soup + 149.7 Portion_Tortilla_Chip
#  + 1915.1 Portion_Vegetbeef_Soup + 134.5 Portion_Wheat_Bread
#  + 132.5 Portion_White_Bread + 0.8 Portion_White_Rice
#  + 333.2 Portion_White_Tuna_in_Water >= 800
#
# SodiumMaximum: 121.8 Portion_2%_Lowfat_Milk
#  + 119.6 Portion_3.3%_Fat,Whole_Milk + 75.4 Portion_Apple_Pie
#  + 151.4 Portion_Bagels + 1.1 Portion_Banana
#  + 951.3 Portion_Beanbacn_Soup,W_Watr + 248.9 Portion_Bologna,Turkey
#  + 41.3 Portion_Butter,Regular + 213.3 Portion_Cap'N_Crunch
#  + 19.2 Portion_Carrots,Raw + 34.8 Portion_Celery,_Raw
#  + 173.7 Portion_Cheddar_Cheese + 307.6 Portion_Cheerios
#  + 1862.2 Portion_Chicknoodl_Soup + 57.8 Portion_Chocolate_Chip_Cookies
#  + 290.5 Portion_Corn_Flks,_Kellogg'S + 4.5 Portion_Couscous
#  + 1076.3 Portion_Crm_Mshrm_Soup,W_Mlk + 461.7 Portion_Frankfurter,_Beef
#  + 68.2 Portion_Frozen_Broccoli + 2.5 Portion_Frozen_Corn + 0.5 Portion_Grapes
#  + 405.1 Portion_Ham,Sliced,Extralean + 563.9 Portion_Hamburger_W_Toppings
#  + 670.3 Portion_Hotdog,_Plain + 279.8 Portion_Kielbasa,Prk
#  + 3.8 Portion_Kiwifruit,Raw,Fresh + 1.8 Portion_Lettuce,Iceberg,Raw
#  + 0.7 Portion_Macaroni,Ckd + 16.5 Portion_Malt_O_Meal,Choc
#  + 992 Portion_New_E_Clamchwd,W_Mlk + 1864.9 Portion_Neweng_Clamchwd
#  + 2.3 Portion_Oatmeal + 68.9 Portion_Oatmeal_Cookies
#  + 155.5 Portion_Peanut_Butter + 1.5 Portion_Peppers,_Sweet,_Raw
#  + 267 Portion_Pizza_W_Pepperoni + 140 Portion_Poached_Eggs
#  + 1.1 Portion_Popcorn,Air_Popped + 38.4 Portion_Pork
#  + 212.6 Portion_Potato_Chips,Bbqflvr + 15.2 Portion_Potatoes,_Baked
#  + 486.2 Portion_Pretzels + 204.4 Portion_Raisin_Brn,_Kellg'S
#  + 340.8 Portion_Rice_Krispies + 125.6 Portion_Roasted_Chicken
#  + 121.2 Portion_Sardines_in_Oil + 168 Portion_Scrambled_Eggs
#  + 126.2 Portion_Skim_Milk + 1237.1 Portion_Spaghetti_W__Sauce
#  + 265.5 Portion_Special_K + 964.8 Portion_Splt_Pea&Hamsoup + 802 Portion_Taco
#  + 8.1 Portion_Tofu + 11.1 Portion_Tomato,Red,Ripe,Raw
#  + 1744.4 Portion_Tomato_Soup + 149.7 Portion_Tortilla_Chip
#  + 1915.1 Portion_Vegetbeef_Soup + 134.5 Portion_Wheat_Bread
#  + 132.5 Portion_White_Bread + 0.8 Portion_White_Rice
#  + 333.2 Portion_White_Tuna_in_Water <= 2000
#
# CarbsMinimum: 11.7 Portion_2%_Lowfat_Milk + 11.4 Portion_3.3%_Fat,Whole_Milk
#  + 21 Portion_Apple,Raw,W_Skin + 9.6 Portion_Apple_Pie + 15.1 Portion_Bagels
#  + 26.7 Portion_Banana + 22.8 Portion_Beanbacn_Soup,W_Watr
#  + 0.3 Portion_Bologna,Turkey + 23 Portion_Cap'N_Crunch
#  + 5.6 Portion_Carrots,Raw + 1.5 Portion_Celery,_Raw
#  + 0.4 Portion_Cheddar_Cheese + 19.6 Portion_Cheerios
#  + 18.7 Portion_Chicknoodl_Soup + 9.3 Portion_Chocolate_Chip_Cookies
#  + 24.5 Portion_Corn_Flks,_Kellogg'S + 20.9 Portion_Couscous
#  + 15 Portion_Crm_Mshrm_Soup,W_Mlk + 0.8 Portion_Frankfurter,_Beef
#  + 13.6 Portion_Frozen_Broccoli + 17.1 Portion_Frozen_Corn
#  + 4.1 Portion_Grapes + 0.3 Portion_Ham,Sliced,Extralean
#  + 32.7 Portion_Hamburger_W_Toppings + 18 Portion_Hotdog,_Plain
#  + 0.6 Portion_Kielbasa,Prk + 11.3 Portion_Kiwifruit,Raw,Fresh
#  + 0.4 Portion_Lettuce,Iceberg,Raw + 19.8 Portion_Macaroni,Ckd
#  + 128.2 Portion_Malt_O_Meal,Choc + 16.6 Portion_New_E_Clamchwd,W_Mlk
#  + 21.8 Portion_Neweng_Clamchwd + 25.3 Portion_Oatmeal
#  + 12.4 Portion_Oatmeal_Cookies + 15.4 Portion_Oranges
#  + 6.9 Portion_Peanut_Butter + 4.8 Portion_Peppers,_Sweet,_Raw
#  + 19.9 Portion_Pizza_W_Pepperoni + 0.6 Portion_Poached_Eggs
#  + 22.1 Portion_Popcorn,Air_Popped + 15 Portion_Potato_Chips,Bbqflvr
#  + 39.9 Portion_Potatoes,_Baked + 22.5 Portion_Pretzels
#  + 27.9 Portion_Raisin_Brn,_Kellg'S + 24.8 Portion_Rice_Krispies
#  + 1.3 Portion_Scrambled_Eggs + 11.9 Portion_Skim_Milk
#  + 58.3 Portion_Spaghetti_W__Sauce + 21.3 Portion_Special_K
#  + 26.8 Portion_Splt_Pea&Hamsoup + 26.7 Portion_Taco + 2.2 Portion_Tofu
#  + 5.7 Portion_Tomato,Red,Ripe,Raw + 33.2 Portion_Tomato_Soup
#  + 17.8 Portion_Tortilla_Chip + 20.4 Portion_Vegetbeef_Soup
#  + 12.4 Portion_Wheat_Bread + 11.8 Portion_White_Bread
#  + 22.3 Portion_White_Rice >= 130
#
# CarbsMaximum: 11.7 Portion_2%_Lowfat_Milk + 11.4 Portion_3.3%_Fat,Whole_Milk
#  + 21 Portion_Apple,Raw,W_Skin + 9.6 Portion_Apple_Pie + 15.1 Portion_Bagels
#  + 26.7 Portion_Banana + 22.8 Portion_Beanbacn_Soup,W_Watr
#  + 0.3 Portion_Bologna,Turkey + 23 Portion_Cap'N_Crunch
#  + 5.6 Portion_Carrots,Raw + 1.5 Portion_Celery,_Raw
#  + 0.4 Portion_Cheddar_Cheese + 19.6 Portion_Cheerios
#  + 18.7 Portion_Chicknoodl_Soup + 9.3 Portion_Chocolate_Chip_Cookies
#  + 24.5 Portion_Corn_Flks,_Kellogg'S + 20.9 Portion_Couscous
#  + 15 Portion_Crm_Mshrm_Soup,W_Mlk + 0.8 Portion_Frankfurter,_Beef
#  + 13.6 Portion_Frozen_Broccoli + 17.1 Portion_Frozen_Corn
#  + 4.1 Portion_Grapes + 0.3 Portion_Ham,Sliced,Extralean
#  + 32.7 Portion_Hamburger_W_Toppings + 18 Portion_Hotdog,_Plain
#  + 0.6 Portion_Kielbasa,Prk + 11.3 Portion_Kiwifruit,Raw,Fresh
#  + 0.4 Portion_Lettuce,Iceberg,Raw + 19.8 Portion_Macaroni,Ckd
#  + 128.2 Portion_Malt_O_Meal,Choc + 16.6 Portion_New_E_Clamchwd,W_Mlk
#  + 21.8 Portion_Neweng_Clamchwd + 25.3 Portion_Oatmeal
#  + 12.4 Portion_Oatmeal_Cookies + 15.4 Portion_Oranges
#  + 6.9 Portion_Peanut_Butter + 4.8 Portion_Peppers,_Sweet,_Raw
#  + 19.9 Portion_Pizza_W_Pepperoni + 0.6 Portion_Poached_Eggs
#  + 22.1 Portion_Popcorn,Air_Popped + 15 Portion_Potato_Chips,Bbqflvr
#  + 39.9 Portion_Potatoes,_Baked + 22.5 Portion_Pretzels
#  + 27.9 Portion_Raisin_Brn,_Kellg'S + 24.8 Portion_Rice_Krispies
#  + 1.3 Portion_Scrambled_Eggs + 11.9 Portion_Skim_Milk
#  + 58.3 Portion_Spaghetti_W__Sauce + 21.3 Portion_Special_K
#  + 26.8 Portion_Splt_Pea&Hamsoup + 26.7 Portion_Taco + 2.2 Portion_Tofu
#  + 5.7 Portion_Tomato,Red,Ripe,Raw + 33.2 Portion_Tomato_Soup
#  + 17.8 Portion_Tortilla_Chip + 20.4 Portion_Vegetbeef_Soup
#  + 12.4 Portion_Wheat_Bread + 11.8 Portion_White_Bread
#  + 22.3 Portion_White_Rice <= 450
#
# FiberMinimum: 3.7 Portion_Apple,Raw,W_Skin + 0.5 Portion_Apple_Pie
#  + 0.6 Portion_Bagels + 2.7 Portion_Banana + 8.6 Portion_Beanbacn_Soup,W_Watr
#  + 0.5 Portion_Cap'N_Crunch + 1.6 Portion_Carrots,Raw
#  + 0.7 Portion_Celery,_Raw + 2 Portion_Cheerios + 1.5 Portion_Chicknoodl_Soup
#  + 0.7 Portion_Corn_Flks,_Kellogg'S + 1.3 Portion_Couscous
#  + 0.5 Portion_Crm_Mshrm_Soup,W_Mlk + 8.5 Portion_Frozen_Broccoli
#  + 2 Portion_Frozen_Corn + 0.2 Portion_Grapes
#  + 2.6 Portion_Kiwifruit,Raw,Fresh + 0.3 Portion_Lettuce,Iceberg,Raw
#  + 0.9 Portion_Macaroni,Ckd + 1.5 Portion_New_E_Clamchwd,W_Mlk
#  + 1.5 Portion_Neweng_Clamchwd + 4 Portion_Oatmeal
#  + 0.6 Portion_Oatmeal_Cookies + 3.1 Portion_Oranges
#  + 2.1 Portion_Peanut_Butter + 1.3 Portion_Peppers,_Sweet,_Raw
#  + 4.3 Portion_Popcorn,Air_Popped + 1.2 Portion_Potato_Chips,Bbqflvr
#  + 3.2 Portion_Potatoes,_Baked + 0.9 Portion_Pretzels
#  + 4 Portion_Raisin_Brn,_Kellg'S + 0.4 Portion_Rice_Krispies
#  + 11.6 Portion_Spaghetti_W__Sauce + 0.7 Portion_Special_K
#  + 4.1 Portion_Splt_Pea&Hamsoup + 1.4 Portion_Tofu
#  + 1.4 Portion_Tomato,Red,Ripe,Raw + Portion_Tomato_Soup
#  + 1.8 Portion_Tortilla_Chip + 4 Portion_Vegetbeef_Soup
#  + 1.3 Portion_Wheat_Bread + 1.1 Portion_White_Bread + 0.3 Portion_White_Rice
#  >= 125
#
# FiberMaximum: 3.7 Portion_Apple,Raw,W_Skin + 0.5 Portion_Apple_Pie
#  + 0.6 Portion_Bagels + 2.7 Portion_Banana + 8.6 Portion_Beanbacn_Soup,W_Watr
#  + 0.5 Portion_Cap'N_Crunch + 1.6 Portion_Carrots,Raw
#  + 0.7 Portion_Celery,_Raw + 2 Portion_Cheerios + 1.5 Portion_Chicknoodl_Soup
#  + 0.7 Portion_Corn_Flks,_Kellogg'S + 1.3 Portion_Couscous
#  + 0.5 Portion_Crm_Mshrm_Soup,W_Mlk + 8.5 Portion_Frozen_Broccoli
#  + 2 Portion_Frozen_Corn + 0.2 Portion_Grapes
#  + 2.6 Portion_Kiwifruit,Raw,Fresh + 0.3 Portion_Lettuce,Iceberg,Raw
#  + 0.9 Portion_Macaroni,Ckd + 1.5 Portion_New_E_Clamchwd,W_Mlk
#  + 1.5 Portion_Neweng_Clamchwd + 4 Portion_Oatmeal
#  + 0.6 Portion_Oatmeal_Cookies + 3.1 Portion_Oranges
#  + 2.1 Portion_Peanut_Butter + 1.3 Portion_Peppers,_Sweet,_Raw
#  + 4.3 Portion_Popcorn,Air_Popped + 1.2 Portion_Potato_Chips,Bbqflvr
#  + 3.2 Portion_Potatoes,_Baked + 0.9 Portion_Pretzels
#  + 4 Portion_Raisin_Brn,_Kellg'S + 0.4 Portion_Rice_Krispies
#  + 11.6 Portion_Spaghetti_W__Sauce + 0.7 Portion_Special_K
#  + 4.1 Portion_Splt_Pea&Hamsoup + 1.4 Portion_Tofu
#  + 1.4 Portion_Tomato,Red,Ripe,Raw + Portion_Tomato_Soup
#  + 1.8 Portion_Tortilla_Chip + 4 Portion_Vegetbeef_Soup
#  + 1.3 Portion_Wheat_Bread + 1.1 Portion_White_Bread + 0.3 Portion_White_Rice
#  <= 250
#
# ProteinMinimum: 8.1 Portion_2%_Lowfat_Milk + 8 Portion_3.3%_Fat,Whole_Milk
#  + 0.3 Portion_Apple,Raw,W_Skin + 0.5 Portion_Apple_Pie + 3 Portion_Bagels
#  + 1.2 Portion_Banana + 7.9 Portion_Beanbacn_Soup,W_Watr
#  + 3.9 Portion_Bologna,Turkey + 1.4 Portion_Cap'N_Crunch
#  + 0.6 Portion_Carrots,Raw + 0.3 Portion_Celery,_Raw
#  + 7 Portion_Cheddar_Cheese + 4.3 Portion_Cheerios
#  + 7.9 Portion_Chicknoodl_Soup + 0.9 Portion_Chocolate_Chip_Cookies
#  + 2.3 Portion_Corn_Flks,_Kellogg'S + 3.4 Portion_Couscous
#  + 6.1 Portion_Crm_Mshrm_Soup,W_Mlk + 5.4 Portion_Frankfurter,_Beef
#  + 8 Portion_Frozen_Broccoli + 2.5 Portion_Frozen_Corn + 0.2 Portion_Grapes
#  + 5.5 Portion_Ham,Sliced,Extralean + 13.6 Portion_Hamburger_W_Toppings
#  + 10.4 Portion_Hotdog,_Plain + 3.4 Portion_Kielbasa,Prk
#  + 0.8 Portion_Kiwifruit,Raw,Fresh + 0.2 Portion_Lettuce,Iceberg,Raw
#  + 3.3 Portion_Macaroni,Ckd + 17.3 Portion_Malt_O_Meal,Choc
#  + 9.5 Portion_New_E_Clamchwd,W_Mlk + 10.9 Portion_Neweng_Clamchwd
#  + 6.1 Portion_Oatmeal + 1.1 Portion_Oatmeal_Cookies + 1.2 Portion_Oranges
#  + 7.7 Portion_Peanut_Butter + 0.7 Portion_Peppers,_Sweet,_Raw
#  + 10.1 Portion_Pizza_W_Pepperoni + 6.2 Portion_Poached_Eggs
#  + 3.4 Portion_Popcorn,Air_Popped + 13.8 Portion_Pork
#  + 2.2 Portion_Potato_Chips,Bbqflvr + 3.7 Portion_Potatoes,_Baked
#  + 2.6 Portion_Pretzels + 4 Portion_Raisin_Brn,_Kellg'S
#  + 1.9 Portion_Rice_Krispies + 42.2 Portion_Roasted_Chicken
#  + 5.9 Portion_Sardines_in_Oil + 6.7 Portion_Scrambled_Eggs
#  + 8.4 Portion_Skim_Milk + 8.2 Portion_Spaghetti_W__Sauce
#  + 5.6 Portion_Special_K + 11.1 Portion_Splt_Pea&Hamsoup + 20.7 Portion_Taco
#  + 9.4 Portion_Tofu + Portion_Tomato,Red,Ripe,Raw + 4.1 Portion_Tomato_Soup
#  + 2 Portion_Tortilla_Chip + 11.2 Portion_Vegetbeef_Soup
#  + 2.2 Portion_Wheat_Bread + 2.3 Portion_White_Bread + 2.1 Portion_White_Rice
#  + 22.7 Portion_White_Tuna_in_Water >= 60
#
# ProteinMaximum: 8.1 Portion_2%_Lowfat_Milk + 8 Portion_3.3%_Fat,Whole_Milk
#  + 0.3 Portion_Apple,Raw,W_Skin + 0.5 Portion_Apple_Pie + 3 Portion_Bagels
#  + 1.2 Portion_Banana + 7.9 Portion_Beanbacn_Soup,W_Watr
#  + 3.9 Portion_Bologna,Turkey + 1.4 Portion_Cap'N_Crunch
#  + 0.6 Portion_Carrots,Raw + 0.3 Portion_Celery,_Raw
#  + 7 Portion_Cheddar_Cheese + 4.3 Portion_Cheerios
#  + 7.9 Portion_Chicknoodl_Soup + 0.9 Portion_Chocolate_Chip_Cookies
#  + 2.3 Portion_Corn_Flks,_Kellogg'S + 3.4 Portion_Couscous
#  + 6.1 Portion_Crm_Mshrm_Soup,W_Mlk + 5.4 Portion_Frankfurter,_Beef
#  + 8 Portion_Frozen_Broccoli + 2.5 Portion_Frozen_Corn + 0.2 Portion_Grapes
#  + 5.5 Portion_Ham,Sliced,Extralean + 13.6 Portion_Hamburger_W_Toppings
#  + 10.4 Portion_Hotdog,_Plain + 3.4 Portion_Kielbasa,Prk
#  + 0.8 Portion_Kiwifruit,Raw,Fresh + 0.2 Portion_Lettuce,Iceberg,Raw
#  + 3.3 Portion_Macaroni,Ckd + 17.3 Portion_Malt_O_Meal,Choc
#  + 9.5 Portion_New_E_Clamchwd,W_Mlk + 10.9 Portion_Neweng_Clamchwd
#  + 6.1 Portion_Oatmeal + 1.1 Portion_Oatmeal_Cookies + 1.2 Portion_Oranges
#  + 7.7 Portion_Peanut_Butter + 0.7 Portion_Peppers,_Sweet,_Raw
#  + 10.1 Portion_Pizza_W_Pepperoni + 6.2 Portion_Poached_Eggs
#  + 3.4 Portion_Popcorn,Air_Popped + 13.8 Portion_Pork
#  + 2.2 Portion_Potato_Chips,Bbqflvr + 3.7 Portion_Potatoes,_Baked
#  + 2.6 Portion_Pretzels + 4 Portion_Raisin_Brn,_Kellg'S
#  + 1.9 Portion_Rice_Krispies + 42.2 Portion_Roasted_Chicken
#  + 5.9 Portion_Sardines_in_Oil + 6.7 Portion_Scrambled_Eggs
#  + 8.4 Portion_Skim_Milk + 8.2 Portion_Spaghetti_W__Sauce
#  + 5.6 Portion_Special_K + 11.1 Portion_Splt_Pea&Hamsoup + 20.7 Portion_Taco
#  + 9.4 Portion_Tofu + Portion_Tomato,Red,Ripe,Raw + 4.1 Portion_Tomato_Soup
#  + 2 Portion_Tortilla_Chip + 11.2 Portion_Vegetbeef_Soup
#  + 2.2 Portion_Wheat_Bread + 2.3 Portion_White_Bread + 2.1 Portion_White_Rice
#  + 22.7 Portion_White_Tuna_in_Water <= 100
#
# VitaminAMinimum: 500.2 Portion_2%_Lowfat_Milk
#  + 307.4 Portion_3.3%_Fat,Whole_Milk + 73.1 Portion_Apple,Raw,W_Skin
#  + 35.2 Portion_Apple_Pie + 92.3 Portion_Banana
#  + 888 Portion_Beanbacn_Soup,W_Watr + 152.9 Portion_Butter,Regular
#  + 40.6 Portion_Cap'N_Crunch + 15471 Portion_Carrots,Raw
#  + 53.6 Portion_Celery,_Raw + 296.5 Portion_Cheddar_Cheese
#  + 1252.2 Portion_Cheerios + 1308.7 Portion_Chicknoodl_Soup
#  + 101.8 Portion_Chocolate_Chip_Cookies + 1252.2 Portion_Corn_Flks,_Kellogg'S
#  + 153.8 Portion_Crm_Mshrm_Soup,W_Mlk + 5867.4 Portion_Frozen_Broccoli
#  + 106.6 Portion_Frozen_Corn + 24 Portion_Grapes
#  + 126.3 Portion_Hamburger_W_Toppings + 133 Portion_Kiwifruit,Raw,Fresh
#  + 66 Portion_Lettuce,Iceberg,Raw + 163.7 Portion_New_E_Clamchwd,W_Mlk
#  + 20.1 Portion_Neweng_Clamchwd + 37.4 Portion_Oatmeal
#  + 2.9 Portion_Oatmeal_Cookies + 268.6 Portion_Oranges
#  + 467.7 Portion_Peppers,_Sweet,_Raw + 281.9 Portion_Pizza_W_Pepperoni
#  + 316 Portion_Poached_Eggs + 55.6 Portion_Popcorn,Air_Popped
#  + 14.7 Portion_Pork + 61.5 Portion_Potato_Chips,Bbqflvr
#  + 1250.2 Portion_Raisin_Brn,_Kellg'S + 1252.2 Portion_Rice_Krispies
#  + 77.4 Portion_Roasted_Chicken + 53.8 Portion_Sardines_in_Oil
#  + 409.2 Portion_Scrambled_Eggs + 499.8 Portion_Skim_Milk
#  + 3055.2 Portion_Spaghetti_W__Sauce + 1252.2 Portion_Special_K
#  + 4872 Portion_Splt_Pea&Hamsoup + 855 Portion_Taco + 98.6 Portion_Tofu
#  + 766.3 Portion_Tomato,Red,Ripe,Raw + 1393 Portion_Tomato_Soup
#  + 55.6 Portion_Tortilla_Chip + 3785.1 Portion_Vegetbeef_Soup
#  + 68 Portion_White_Tuna_in_Water >= 1000
#
# VitaminAMaximum: 500.2 Portion_2%_Lowfat_Milk
#  + 307.4 Portion_3.3%_Fat,Whole_Milk + 73.1 Portion_Apple,Raw,W_Skin
#  + 35.2 Portion_Apple_Pie + 92.3 Portion_Banana
#  + 888 Portion_Beanbacn_Soup,W_Watr + 152.9 Portion_Butter,Regular
#  + 40.6 Portion_Cap'N_Crunch + 15471 Portion_Carrots,Raw
#  + 53.6 Portion_Celery,_Raw + 296.5 Portion_Cheddar_Cheese
#  + 1252.2 Portion_Cheerios + 1308.7 Portion_Chicknoodl_Soup
#  + 101.8 Portion_Chocolate_Chip_Cookies + 1252.2 Portion_Corn_Flks,_Kellogg'S
#  + 153.8 Portion_Crm_Mshrm_Soup,W_Mlk + 5867.4 Portion_Frozen_Broccoli
#  + 106.6 Portion_Frozen_Corn + 24 Portion_Grapes
#  + 126.3 Portion_Hamburger_W_Toppings + 133 Portion_Kiwifruit,Raw,Fresh
#  + 66 Portion_Lettuce,Iceberg,Raw + 163.7 Portion_New_E_Clamchwd,W_Mlk
#  + 20.1 Portion_Neweng_Clamchwd + 37.4 Portion_Oatmeal
#  + 2.9 Portion_Oatmeal_Cookies + 268.6 Portion_Oranges
#  + 467.7 Portion_Peppers,_Sweet,_Raw + 281.9 Portion_Pizza_W_Pepperoni
#  + 316 Portion_Poached_Eggs + 55.6 Portion_Popcorn,Air_Popped
#  + 14.7 Portion_Pork + 61.5 Portion_Potato_Chips,Bbqflvr
#  + 1250.2 Portion_Raisin_Brn,_Kellg'S + 1252.2 Portion_Rice_Krispies
#  + 77.4 Portion_Roasted_Chicken + 53.8 Portion_Sardines_in_Oil
#  + 409.2 Portion_Scrambled_Eggs + 499.8 Portion_Skim_Milk
#  + 3055.2 Portion_Spaghetti_W__Sauce + 1252.2 Portion_Special_K
#  + 4872 Portion_Splt_Pea&Hamsoup + 855 Portion_Taco + 98.6 Portion_Tofu
#  + 766.3 Portion_Tomato,Red,Ripe,Raw + 1393 Portion_Tomato_Soup
#  + 55.6 Portion_Tortilla_Chip + 3785.1 Portion_Vegetbeef_Soup
#  + 68 Portion_White_Tuna_in_Water <= 10000
#
# VitaminCMinimum: 2.3 Portion_2%_Lowfat_Milk + 2.3 Portion_3.3%_Fat,Whole_Milk
#  + 7.9 Portion_Apple,Raw,W_Skin + 0.9 Portion_Apple_Pie + 10.4 Portion_Banana
#  + 1.5 Portion_Beanbacn_Soup,W_Watr + 5.1 Portion_Carrots,Raw
#  + 2.8 Portion_Celery,_Raw + 15.1 Portion_Cheerios
#  + 15.1 Portion_Corn_Flks,_Kellogg'S + 2.2 Portion_Crm_Mshrm_Soup,W_Mlk
#  + 10.8 Portion_Frankfurter,_Beef + 160.2 Portion_Frozen_Broccoli
#  + 5.2 Portion_Frozen_Corn + Portion_Grapes + 7.4 Portion_Ham,Sliced,Extralean
#  + 2.6 Portion_Hamburger_W_Toppings + 0.1 Portion_Hotdog,_Plain
#  + 5.5 Portion_Kielbasa,Prk + 74.5 Portion_Kiwifruit,Raw,Fresh
#  + 0.8 Portion_Lettuce,Iceberg,Raw + 3.5 Portion_New_E_Clamchwd,W_Mlk
#  + 4.8 Portion_Neweng_Clamchwd + 0.1 Portion_Oatmeal_Cookies
#  + 69.7 Portion_Oranges + 66.1 Portion_Peppers,_Sweet,_Raw
#  + 1.6 Portion_Pizza_W_Pepperoni + 9.6 Portion_Potato_Chips,Bbqflvr
#  + 15.6 Portion_Potatoes,_Baked + 15.1 Portion_Rice_Krispies
#  + 0.1 Portion_Scrambled_Eggs + 2.4 Portion_Skim_Milk
#  + 27.9 Portion_Spaghetti_W__Sauce + 15.1 Portion_Special_K
#  + 7 Portion_Splt_Pea&Hamsoup + 2.2 Portion_Taco + 0.1 Portion_Tofu
#  + 23.5 Portion_Tomato,Red,Ripe,Raw + 133 Portion_Tomato_Soup
#  + 4.8 Portion_Vegetbeef_Soup >= 400
#
# VitaminCMaximum: 2.3 Portion_2%_Lowfat_Milk + 2.3 Portion_3.3%_Fat,Whole_Milk
#  + 7.9 Portion_Apple,Raw,W_Skin + 0.9 Portion_Apple_Pie + 10.4 Portion_Banana
#  + 1.5 Portion_Beanbacn_Soup,W_Watr + 5.1 Portion_Carrots,Raw
#  + 2.8 Portion_Celery,_Raw + 15.1 Portion_Cheerios
#  + 15.1 Portion_Corn_Flks,_Kellogg'S + 2.2 Portion_Crm_Mshrm_Soup,W_Mlk
#  + 10.8 Portion_Frankfurter,_Beef + 160.2 Portion_Frozen_Broccoli
#  + 5.2 Portion_Frozen_Corn + Portion_Grapes + 7.4 Portion_Ham,Sliced,Extralean
#  + 2.6 Portion_Hamburger_W_Toppings + 0.1 Portion_Hotdog,_Plain
#  + 5.5 Portion_Kielbasa,Prk + 74.5 Portion_Kiwifruit,Raw,Fresh
#  + 0.8 Portion_Lettuce,Iceberg,Raw + 3.5 Portion_New_E_Clamchwd,W_Mlk
#  + 4.8 Portion_Neweng_Clamchwd + 0.1 Portion_Oatmeal_Cookies
#  + 69.7 Portion_Oranges + 66.1 Portion_Peppers,_Sweet,_Raw
#  + 1.6 Portion_Pizza_W_Pepperoni + 9.6 Portion_Potato_Chips,Bbqflvr
#  + 15.6 Portion_Potatoes,_Baked + 15.1 Portion_Rice_Krispies
#  + 0.1 Portion_Scrambled_Eggs + 2.4 Portion_Skim_Milk
#  + 27.9 Portion_Spaghetti_W__Sauce + 15.1 Portion_Special_K
#  + 7 Portion_Splt_Pea&Hamsoup + 2.2 Portion_Taco + 0.1 Portion_Tofu
#  + 23.5 Portion_Tomato,Red,Ripe,Raw + 133 Portion_Tomato_Soup
#  + 4.8 Portion_Vegetbeef_Soup <= 5000
#
# CalciumMinimum: 296.7 Portion_2%_Lowfat_Milk
#  + 291.3 Portion_3.3%_Fat,Whole_Milk + 9.7 Portion_Apple,Raw,W_Skin
#  + 3.1 Portion_Apple_Pie + 21 Portion_Bagels + 6.8 Portion_Banana
#  + 81 Portion_Beanbacn_Soup,W_Watr + 23.8 Portion_Bologna,Turkey
#  + 1.2 Portion_Butter,Regular + 4.8 Portion_Cap'N_Crunch
#  + 14.9 Portion_Carrots,Raw + 16 Portion_Celery,_Raw
#  + 202 Portion_Cheddar_Cheese + 48.6 Portion_Cheerios
#  + 27.1 Portion_Chicknoodl_Soup + 6.2 Portion_Chocolate_Chip_Cookies
#  + 0.9 Portion_Corn_Flks,_Kellogg'S + 7.2 Portion_Couscous
#  + 178.6 Portion_Crm_Mshrm_Soup,W_Mlk + 9 Portion_Frankfurter,_Beef
#  + 159 Portion_Frozen_Broccoli + 3.3 Portion_Frozen_Corn + 3.4 Portion_Grapes
#  + 2 Portion_Ham,Sliced,Extralean + 51.4 Portion_Hamburger_W_Toppings
#  + 23.5 Portion_Hotdog,_Plain + 11.4 Portion_Kielbasa,Prk
#  + 19.8 Portion_Kiwifruit,Raw,Fresh + 3.8 Portion_Lettuce,Iceberg,Raw
#  + 4.9 Portion_Macaroni,Ckd + 23.1 Portion_Malt_O_Meal,Choc
#  + 186 Portion_New_E_Clamchwd,W_Mlk + 82.8 Portion_Neweng_Clamchwd
#  + 18.7 Portion_Oatmeal + 6.7 Portion_Oatmeal_Cookies + 52.4 Portion_Oranges
#  + 13.1 Portion_Peanut_Butter + 6.7 Portion_Peppers,_Sweet,_Raw
#  + 64.6 Portion_Pizza_W_Pepperoni + 24.5 Portion_Poached_Eggs
#  + 2.8 Portion_Popcorn,Air_Popped + 59.9 Portion_Pork
#  + 14.2 Portion_Potato_Chips,Bbqflvr + 22.7 Portion_Potatoes,_Baked
#  + 10.2 Portion_Pretzels + 12.9 Portion_Raisin_Brn,_Kellg'S
#  + 4 Portion_Rice_Krispies + 21.9 Portion_Roasted_Chicken
#  + 91.7 Portion_Sardines_in_Oil + 42.6 Portion_Scrambled_Eggs
#  + 302.3 Portion_Skim_Milk + 80.2 Portion_Spaghetti_W__Sauce
#  + 8.2 Portion_Special_K + 33.6 Portion_Splt_Pea&Hamsoup + 220.6 Portion_Taco
#  + 121.8 Portion_Tofu + 6.2 Portion_Tomato,Red,Ripe,Raw
#  + 27.6 Portion_Tomato_Soup + 43.7 Portion_Tortilla_Chip
#  + 32.6 Portion_Vegetbeef_Soup + 10.8 Portion_Wheat_Bread
#  + 26.2 Portion_White_Bread + 7.9 Portion_White_Rice
#  + 3.4 Portion_White_Tuna_in_Water >= 700
#
# CalciumMaximum: 296.7 Portion_2%_Lowfat_Milk
#  + 291.3 Portion_3.3%_Fat,Whole_Milk + 9.7 Portion_Apple,Raw,W_Skin
#  + 3.1 Portion_Apple_Pie + 21 Portion_Bagels + 6.8 Portion_Banana
#  + 81 Portion_Beanbacn_Soup,W_Watr + 23.8 Portion_Bologna,Turkey
#  + 1.2 Portion_Butter,Regular + 4.8 Portion_Cap'N_Crunch
#  + 14.9 Portion_Carrots,Raw + 16 Portion_Celery,_Raw
#  + 202 Portion_Cheddar_Cheese + 48.6 Portion_Cheerios
#  + 27.1 Portion_Chicknoodl_Soup + 6.2 Portion_Chocolate_Chip_Cookies
#  + 0.9 Portion_Corn_Flks,_Kellogg'S + 7.2 Portion_Couscous
#  + 178.6 Portion_Crm_Mshrm_Soup,W_Mlk + 9 Portion_Frankfurter,_Beef
#  + 159 Portion_Frozen_Broccoli + 3.3 Portion_Frozen_Corn + 3.4 Portion_Grapes
#  + 2 Portion_Ham,Sliced,Extralean + 51.4 Portion_Hamburger_W_Toppings
#  + 23.5 Portion_Hotdog,_Plain + 11.4 Portion_Kielbasa,Prk
#  + 19.8 Portion_Kiwifruit,Raw,Fresh + 3.8 Portion_Lettuce,Iceberg,Raw
#  + 4.9 Portion_Macaroni,Ckd + 23.1 Portion_Malt_O_Meal,Choc
#  + 186 Portion_New_E_Clamchwd,W_Mlk + 82.8 Portion_Neweng_Clamchwd
#  + 18.7 Portion_Oatmeal + 6.7 Portion_Oatmeal_Cookies + 52.4 Portion_Oranges
#  + 13.1 Portion_Peanut_Butter + 6.7 Portion_Peppers,_Sweet,_Raw
#  + 64.6 Portion_Pizza_W_Pepperoni + 24.5 Portion_Poached_Eggs
#  + 2.8 Portion_Popcorn,Air_Popped + 59.9 Portion_Pork
#  + 14.2 Portion_Potato_Chips,Bbqflvr + 22.7 Portion_Potatoes,_Baked
#  + 10.2 Portion_Pretzels + 12.9 Portion_Raisin_Brn,_Kellg'S
#  + 4 Portion_Rice_Krispies + 21.9 Portion_Roasted_Chicken
#  + 91.7 Portion_Sardines_in_Oil + 42.6 Portion_Scrambled_Eggs
#  + 302.3 Portion_Skim_Milk + 80.2 Portion_Spaghetti_W__Sauce
#  + 8.2 Portion_Special_K + 33.6 Portion_Splt_Pea&Hamsoup + 220.6 Portion_Taco
#  + 121.8 Portion_Tofu + 6.2 Portion_Tomato,Red,Ripe,Raw
#  + 27.6 Portion_Tomato_Soup + 43.7 Portion_Tortilla_Chip
#  + 32.6 Portion_Vegetbeef_Soup + 10.8 Portion_Wheat_Bread
#  + 26.2 Portion_White_Bread + 7.9 Portion_White_Rice
#  + 3.4 Portion_White_Tuna_in_Water <= 1500
#
# IronMinimum: 0.1 Portion_2%_Lowfat_Milk + 0.1 Portion_3.3%_Fat,Whole_Milk
#  + 0.2 Portion_Apple,Raw,W_Skin + 0.1 Portion_Apple_Pie + Portion_Bagels
#  + 0.4 Portion_Banana + 2 Portion_Beanbacn_Soup,W_Watr
#  + 0.4 Portion_Bologna,Turkey + 7.5 Portion_Cap'N_Crunch
#  + 0.3 Portion_Carrots,Raw + 0.2 Portion_Celery,_Raw
#  + 0.2 Portion_Cheddar_Cheese + 4.5 Portion_Cheerios
#  + 1.5 Portion_Chicknoodl_Soup + 0.4 Portion_Chocolate_Chip_Cookies
#  + 1.8 Portion_Corn_Flks,_Kellogg'S + 0.3 Portion_Couscous
#  + 0.6 Portion_Crm_Mshrm_Soup,W_Mlk + 0.6 Portion_Frankfurter,_Beef
#  + 2.3 Portion_Frozen_Broccoli + 0.3 Portion_Frozen_Corn + 0.1 Portion_Grapes
#  + 0.2 Portion_Ham,Sliced,Extralean + 2.5 Portion_Hamburger_W_Toppings
#  + 2.3 Portion_Hotdog,_Plain + 0.4 Portion_Kielbasa,Prk
#  + 0.3 Portion_Kiwifruit,Raw,Fresh + 0.1 Portion_Lettuce,Iceberg,Raw
#  + Portion_Macaroni,Ckd + 4.7 Portion_Malt_O_Meal,Choc
#  + 1.5 Portion_New_E_Clamchwd,W_Mlk + 2.8 Portion_Neweng_Clamchwd
#  + 1.6 Portion_Oatmeal + 0.5 Portion_Oatmeal_Cookies + 0.1 Portion_Oranges
#  + 0.6 Portion_Peanut_Butter + 0.3 Portion_Peppers,_Sweet,_Raw
#  + 0.9 Portion_Pizza_W_Pepperoni + 0.7 Portion_Poached_Eggs
#  + 0.8 Portion_Popcorn,Air_Popped + 0.4 Portion_Pork
#  + 0.5 Portion_Potato_Chips,Bbqflvr + 4.3 Portion_Potatoes,_Baked
#  + 1.2 Portion_Pretzels + 16.8 Portion_Raisin_Brn,_Kellg'S
#  + 1.8 Portion_Rice_Krispies + 1.8 Portion_Roasted_Chicken
#  + 0.7 Portion_Sardines_in_Oil + 0.7 Portion_Scrambled_Eggs
#  + 0.1 Portion_Skim_Milk + 2.3 Portion_Spaghetti_W__Sauce
#  + 4.5 Portion_Special_K + 2.1 Portion_Splt_Pea&Hamsoup + 2.4 Portion_Taco
#  + 6.2 Portion_Tofu + 0.6 Portion_Tomato,Red,Ripe,Raw
#  + 3.5 Portion_Tomato_Soup + 0.4 Portion_Tortilla_Chip
#  + 2.2 Portion_Vegetbeef_Soup + 0.7 Portion_Wheat_Bread
#  + 0.8 Portion_White_Bread + 0.9 Portion_White_Rice
#  + 0.5 Portion_White_Tuna_in_Water >= 10
#
# IronMaximum: 0.1 Portion_2%_Lowfat_Milk + 0.1 Portion_3.3%_Fat,Whole_Milk
#  + 0.2 Portion_Apple,Raw,W_Skin + 0.1 Portion_Apple_Pie + Portion_Bagels
#  + 0.4 Portion_Banana + 2 Portion_Beanbacn_Soup,W_Watr
#  + 0.4 Portion_Bologna,Turkey + 7.5 Portion_Cap'N_Crunch
#  + 0.3 Portion_Carrots,Raw + 0.2 Portion_Celery,_Raw
#  + 0.2 Portion_Cheddar_Cheese + 4.5 Portion_Cheerios
#  + 1.5 Portion_Chicknoodl_Soup + 0.4 Portion_Chocolate_Chip_Cookies
#  + 1.8 Portion_Corn_Flks,_Kellogg'S + 0.3 Portion_Couscous
#  + 0.6 Portion_Crm_Mshrm_Soup,W_Mlk + 0.6 Portion_Frankfurter,_Beef
#  + 2.3 Portion_Frozen_Broccoli + 0.3 Portion_Frozen_Corn + 0.1 Portion_Grapes
#  + 0.2 Portion_Ham,Sliced,Extralean + 2.5 Portion_Hamburger_W_Toppings
#  + 2.3 Portion_Hotdog,_Plain + 0.4 Portion_Kielbasa,Prk
#  + 0.3 Portion_Kiwifruit,Raw,Fresh + 0.1 Portion_Lettuce,Iceberg,Raw
#  + Portion_Macaroni,Ckd + 4.7 Portion_Malt_O_Meal,Choc
#  + 1.5 Portion_New_E_Clamchwd,W_Mlk + 2.8 Portion_Neweng_Clamchwd
#  + 1.6 Portion_Oatmeal + 0.5 Portion_Oatmeal_Cookies + 0.1 Portion_Oranges
#  + 0.6 Portion_Peanut_Butter + 0.3 Portion_Peppers,_Sweet,_Raw
#  + 0.9 Portion_Pizza_W_Pepperoni + 0.7 Portion_Poached_Eggs
#  + 0.8 Portion_Popcorn,Air_Popped + 0.4 Portion_Pork
#  + 0.5 Portion_Potato_Chips,Bbqflvr + 4.3 Portion_Potatoes,_Baked
#  + 1.2 Portion_Pretzels + 16.8 Portion_Raisin_Brn,_Kellg'S
#  + 1.8 Portion_Rice_Krispies + 1.8 Portion_Roasted_Chicken
#  + 0.7 Portion_Sardines_in_Oil + 0.7 Portion_Scrambled_Eggs
#  + 0.1 Portion_Skim_Milk + 2.3 Portion_Spaghetti_W__Sauce
#  + 4.5 Portion_Special_K + 2.1 Portion_Splt_Pea&Hamsoup + 2.4 Portion_Taco
#  + 6.2 Portion_Tofu + 0.6 Portion_Tomato,Red,Ripe,Raw
#  + 3.5 Portion_Tomato_Soup + 0.4 Portion_Tortilla_Chip
#  + 2.2 Portion_Vegetbeef_Soup + 0.7 Portion_Wheat_Bread
#  + 0.8 Portion_White_Bread + 0.9 Portion_White_Rice
#  + 0.5 Portion_White_Tuna_in_Water <= 40
#
# _C1: Chosen_Celery,_Raw + Chosen_Frozen_Broccoli <= 1
#
# _C2: Chosen_Beanbacn_Soup,W_Watr + Chosen_Bologna,Turkey
#  + Chosen_Frankfurter,_Beef + Chosen_Ham,Sliced,Extralean
#  + Chosen_Hamburger_W_Toppings + Chosen_Hotdog,_Plain + Chosen_Kielbasa,Prk
#  + Chosen_Neweng_Clamchwd + Chosen_Pizza_W_Pepperoni + Chosen_Poached_Eggs
#  + Chosen_Pork + Chosen_Roasted_Chicken + Chosen_Sardines_in_Oil
#  + Chosen_Scrambled_Eggs + Chosen_Vegetbeef_Soup + Chosen_White_Tuna_in_Water
#  >= 3
#
# VARIABLES
# 0 <= Chosen_Beanbacn_Soup,W_Watr <= 1 Integer
# 0 <= Chosen_Bologna,Turkey <= 1 Integer
# 0 <= Chosen_Celery,_Raw <= 1 Integer
# 0 <= Chosen_Frankfurter,_Beef <= 1 Integer
# 0 <= Chosen_Frozen_Broccoli <= 1 Integer
# 0 <= Chosen_Ham,Sliced,Extralean <= 1 Integer
# 0 <= Chosen_Hamburger_W_Toppings <= 1 Integer
# 0 <= Chosen_Hotdog,_Plain <= 1 Integer
# 0 <= Chosen_Kielbasa,Prk <= 1 Integer
# 0 <= Chosen_Neweng_Clamchwd <= 1 Integer
# 0 <= Chosen_Pizza_W_Pepperoni <= 1 Integer
# 0 <= Chosen_Poached_Eggs <= 1 Integer
# 0 <= Chosen_Pork <= 1 Integer
# 0 <= Chosen_Roasted_Chicken <= 1 Integer
# 0 <= Chosen_Sardines_in_Oil <= 1 Integer
# 0 <= Chosen_Scrambled_Eggs <= 1 Integer
# 0 <= Chosen_Vegetbeef_Soup <= 1 Integer
# 0 <= Chosen_White_Tuna_in_Water <= 1 Integer
# Portion_2%_Lowfat_Milk Continuous
# Portion_3.3%_Fat,Whole_Milk Continuous
# Portion_Apple,Raw,W_Skin Continuous
# Portion_Apple_Pie Continuous
# Portion_Bagels Continuous
# Portion_Banana Continuous
# Portion_Beanbacn_Soup,W_Watr Continuous
# Portion_Bologna,Turkey Continuous
# Portion_Butter,Regular Continuous
# Portion_Cap'N_Crunch Continuous
# Portion_Carrots,Raw Continuous
# Portion_Celery,_Raw Continuous
# Portion_Cheddar_Cheese Continuous
# Portion_Cheerios Continuous
# Portion_Chicknoodl_Soup Continuous
# Portion_Chocolate_Chip_Cookies Continuous
# Portion_Corn_Flks,_Kellogg'S Continuous
# Portion_Couscous Continuous
# Portion_Crm_Mshrm_Soup,W_Mlk Continuous
# Portion_Frankfurter,_Beef Continuous
# Portion_Frozen_Broccoli Continuous
# Portion_Frozen_Corn Continuous
# Portion_Grapes Continuous
# Portion_Ham,Sliced,Extralean Continuous
# Portion_Hamburger_W_Toppings Continuous
# Portion_Hotdog,_Plain Continuous
# Portion_Kielbasa,Prk Continuous
# Portion_Kiwifruit,Raw,Fresh Continuous
# Portion_Lettuce,Iceberg,Raw Continuous
# Portion_Macaroni,Ckd Continuous
# Portion_Malt_O_Meal,Choc Continuous
# Portion_New_E_Clamchwd,W_Mlk Continuous
# Portion_Neweng_Clamchwd Continuous
# Portion_Oatmeal Continuous
# Portion_Oatmeal_Cookies Continuous
# Portion_Oranges Continuous
# Portion_Peanut_Butter Continuous
# Portion_Peppers,_Sweet,_Raw Continuous
# Portion_Pizza_W_Pepperoni Continuous
# Portion_Poached_Eggs Continuous
# Portion_Popcorn,Air_Popped Continuous
# Portion_Pork Continuous
# Portion_Potato_Chips,Bbqflvr Continuous
# Portion_Potatoes,_Baked Continuous
# Portion_Pretzels Continuous
# Portion_Raisin_Brn,_Kellg'S Continuous
# Portion_Rice_Krispies Continuous
# Portion_Roasted_Chicken Continuous
# Portion_Sardines_in_Oil Continuous
# Portion_Scrambled_Eggs Continuous
# Portion_Skim_Milk Continuous
# Portion_Spaghetti_W__Sauce Continuous
# Portion_Special_K Continuous
# Portion_Splt_Pea&Hamsoup Continuous
# Portion_Taco Continuous
# Portion_Tofu Continuous
# Portion_Tomato,Red,Ripe,Raw Continuous
# Portion_Tomato_Soup Continuous
# Portion_Tortilla_Chip Continuous
# Portion_Vegetbeef_Soup Continuous
# Portion_Wheat_Bread Continuous
# Portion_White_Bread Continuous
# Portion_White_Rice Continuous
# Portion_White_Tuna_in_Water Continuous

# %% [markdown]
# ### Writing problem data to a `.lp` file

# %%
# The problem data is written to an .lp file
prob.writeLP("SimpleDietProblem.lp")

# %% [markdown]
# ### Run the solver

# %%
# The problem is solved using PuLP's choice of Solver
prob.solve()
# Out:
# 1

# %% [markdown]
# ### Print the problem solution status `'optimal'`, `'infeasible'`, `'unbounded'` etc...

# %%
# The status of the solution is printed to the screen
print("Status:", LpStatus[prob.status])
# Out:
# Status: Optimal

# %% [markdown]
# ### Scan through the problem variables and print out only if the variable quanity is positive i.e. it is included in the optimal solution

# %%
print("The optimal (least cost) balanced diet with additional constraints \
(e.g. at least 3 types of animal protein sources, consists of\n"+"-"*110)
for v in prob.variables():
    if v.varValue>0 and v.name[0]=='P':
        print(v.name, "=", v.varValue)
# Out:
# The optimal (least cost) balanced diet with additional constraints (e.g. at least 3 types of animal protein sources, consists of
# --------------------------------------------------------------------------------------------------------------
# Portion_Celery,_Raw = 52.64371
# Portion_Frozen_Broccoli = 0.25960653
# Portion_Lettuce,Iceberg,Raw = 63.988506
# Portion_Oranges = 2.2929389
# Portion_Poached_Eggs = 0.14184397
# Portion_Popcorn,Air_Popped = 13.869322

# %% [markdown]
# ### Print the optimal diet cost

# %%
print("The total cost of this balanced diet is: ${}".format(round(value(prob.objective),2)))
# Out:
# The total cost of this balanced diet is: $4.34
