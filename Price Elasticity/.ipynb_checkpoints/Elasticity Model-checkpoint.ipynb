# %%
from __future__ import print_function
from statsmodels.compat import lzip
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
data = pd.read_csv('Data/beef.csv')
data.head(10)
# Out:
#    Year  Quarter  Quantity     Price
# 0  1977        1   22.9976  142.1667
# 1  1977        2   22.6131  143.9333
# 2  1977        3   23.4054  146.5000
# 3  1977        4   22.7401  150.8000
# 4  1978        1   22.0441  160.0000
# 5  1978        2   21.7602  182.5333
# 6  1978        3   21.6064  186.2000
# 7  1978        4   21.8814  186.4333
# 8  1979        1   20.5086  211.7000
# 9  1979        2   19.0408  231.5000

# %% [markdown]
# # Level Level Model

# %%
model=ols("Quantity~Price",data=data).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Quantity   R-squared:                       0.901
# Model:                            OLS   Adj. R-squared:                  0.900
# Method:                 Least Squares   F-statistic:                     811.2
# Date:                Wed, 26 Jun 2019   Prob (F-statistic):           1.69e-46
# Time:                        12:12:34   Log-Likelihood:                -77.493
# No. Observations:                  91   AIC:                             159.0
# Df Residuals:                      89   BIC:                             164.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     30.0515      0.413     72.701      0.000      29.230      30.873
# ...

# %%
fig = plt.figure(figsize=(12,8))
fig=sm.graphics.plot_partregress_grid(model, fig=fig)

# %% [markdown]
# he trend indicates that the predictor variables (Price) provides information about the response (Quantity), and data points do not fall further from the regression line,

# %% [markdown]
# # Log Level Model

# %%
model=ols("np.log(Quantity)~Price",data=data).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       np.log(Quantity)   R-squared:                       0.886
# Model:                            OLS   Adj. R-squared:                  0.885
# Method:                 Least Squares   F-statistic:                     693.6
# Date:                Fri, 28 Jun 2019   Prob (F-statistic):           8.65e-44
# Time:                        12:25:50   Log-Likelihood:                 183.61
# No. Observations:                  91   AIC:                            -363.2
# Df Residuals:                      89   BIC:                            -358.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      3.5190      0.023    150.045      0.000       3.472       3.566
# ...

# %%
fig = plt.figure(figsize=(12,8))
fig=sm.graphics.plot_partregress_grid(model, fig=fig)

# %% [markdown]
# # Log Log Model

# %%
model=ols("np.log(Quantity)~np.log(Price)",data=data).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       np.log(Quantity)   R-squared:                       0.852
# Model:                            OLS   Adj. R-squared:                  0.850
# Method:                 Least Squares   F-statistic:                     512.6
# Date:                Sat, 29 Jun 2019   Prob (F-statistic):           1.07e-38
# Time:                        21:03:49   Log-Likelihood:                 171.64
# No. Observations:                  91   AIC:                            -339.3
# Df Residuals:                      89   BIC:                            -334.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
fig = plt.figure(figsize=(12,8))
fig=sm.graphics.plot_partregress_grid(model, fig=fig)

# %% [markdown]
# # Level Log Model

# %%
model=ols("Quantity~np.log(Price)",data=data).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               Quantity   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.875
# Method:                 Least Squares   F-statistic:                     633.8
# Date:                Sat, 29 Jun 2019   Prob (F-statistic):           2.99e-42
# Time:                        21:07:40   Log-Likelihood:                -87.481
# No. Observations:                  91   AIC:                             179.0
# Df Residuals:                      89   BIC:                             184.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
fig = plt.figure(figsize=(12,8))
fig=sm.graphics.plot_partregress_grid(model, fig=fig)
